# %% [markdown]
# # Import libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torchvision.models import vgg16, VGG16_Weights
from torch.utils.data import Dataset, DataLoader, random_split
import pandas as pd
from PIL import Image
import os
import numpy as np

# %% [markdown]
# # Database creations using pytorch Dataset

# %%
class ImageAuthenticityDataset(Dataset):
    """Dataset for image quality assessment."""

    def __init__(self, csv_file, transform=None):
        """
        Args:
            csv_file (string): Path to the CSV file with annotations.
            transform (callable, optional): Optional transform to be applied on a sample.
        """
        self.data = pd.read_csv(csv_file)
        self.transform = transform

    def __len__(self):
        """Returns the number of samples in the dataset."""
        return len(self.data)

    def __getitem__(self, idx):
        """
        Retrieves an image and its labels by index.

        Args:
            idx (int): Index of the sample to retrieve.

        Returns:
            tuple: A tuple (image, labels) where:
                image (PIL.Image): The image.
                labels (torch.Tensor): Tensor containing quality and authenticity scores.
        """
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_name = os.path.join(os.getcwd(), self.data.iloc[idx, 3])  # image_path column
        image = Image.open(img_name).convert('RGB')
        authenticity = self.data.iloc[idx, 1]  # Authenticity column
        labels = torch.tensor([authenticity], dtype=torch.float)


        if self.transform:
            image = self.transform(image)

        return image, labels

# %% [markdown]
# # Definitions of the models

# %%
class AuthenticityPredictor(nn.Module):
    def __init__(self, freeze_backbone=True):
        super().__init__()
        # Load pre-trained VGG16
        vgg = vgg16(weights=VGG16_Weights.DEFAULT)
        
        # Freeze backbone if requested
        if freeze_backbone:
            for param in vgg.features.parameters():
                param.requires_grad = False
                
        # Extract features up to fc2
        self.features = vgg.features
        self.avgpool = vgg.avgpool
        self.fc1 = vgg.classifier[:-1]  # Up to fc2 (4096 -> 128)
        
        # New regression head
        self.regression_head = nn.Sequential(
            nn.Linear(4096, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, 1)  # Predict authenticity
        )
        
    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        features = self.fc1(x)
        predictions = self.regression_head(features)
        return predictions, features

# %% [markdown]
# # Utility functions for training and evaluation

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=10, device='cuda'):
    """
    Trains the model.

    Args:
        model (nn.Module): The model to train.
        dataloaders (dict): A dictionary containing the training and validation data loaders.
        criterion (nn.Module): The loss function.
        optimizer (optim.Optimizer): The optimizer.
        num_epochs (int): Number of epochs to train for. Defaults to 10.
        device (str): Device to use for training ('cuda' or 'cpu'). Defaults to 'cuda'.

    Returns:
        nn.Module: The trained model.
    """
    model.to(device)
    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        for phase in ['train', 'val']:  # Iterate over training and validation phases
            print(f'{phase} phase')
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0

            for inputs, labels in dataloaders[phase]:  # Iterate over data in the current phase
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):  # Enable gradients only during training
                    outputs, _ = model(inputs)
                    loss = criterion(outputs, labels)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)

            print(f'{phase} Loss: {epoch_loss:.4f}') # Print loss for the current phase

    print("Finished Training")
    return model

def test_model(model, dataloader, criterion, device='cuda'):

    """
    Tests the model on the test dataset.

    Args:
        model (nn.Module): The trained model.
        dataloader (DataLoader): The test data loader.
        criterion (nn.Module): The loss function.
        device (str): Device to use for testing ('cuda' or 'cpu'). Defaults to 'cuda'.

    Returns:
        float: The average loss on the test dataset.
    """
    model.eval()  # Set the model to evaluation mode
    model.to(device)
    running_loss = 0.0

    with torch.no_grad():  # Disable gradient calculation
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs, _ = model(inputs)
            
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)

    test_loss = running_loss / len(dataloader.dataset)
    print(f'Test Loss: {test_loss:.4f}')
    return test_loss

def get_predictions(model, dataloader, device)-> tuple[torch.Tensor, torch.Tensor]:
    """
    Get predictions from the model.

    Args:
        model (nn.Module): The trained model.
        dataloader (DataLoader): The data loader.

    Returns:
        tuple: A tuple (predictions, labels) where:
            predictions (torch.Tensor): Predictions from the model.
            labels (torch.Tensor): Ground truth labels.
    """
    model.eval()  # Set the model to evaluation mode
    model.to(device)
    predictions = []
    labels = []

    with torch.no_grad():  # Disable gradient calculation
        for inputs, target in dataloader:
            outputs, _ = model(inputs.to(device))
            predictions.append(outputs)
            labels.append(target)

    #move to cpu and concatenate
    predictions = torch.cat(predictions).cpu()
    labels = torch.cat(labels).cpu()

    return predictions, labels

def get_regression_errors(tuple: tuple[torch.Tensor, torch.Tensor]) -> tuple[torch.Tensor, torch.Tensor]:
    """
    Get regression errors.

    Args:
        tuple: A tuple (predictions, labels) where:
            predictions (torch.Tensor): Predictions from the model.
            labels (torch.Tensor): Ground truth labels.

    Returns:
        tuple: A tuple (quality_errors, authenticity_errors) where:
            quality_errors (torch.Tensor): Quality errors.
            authenticity_errors (torch.Tensor): Authenticity errors.
    """
    predictions, labels = tuple
    authenticity_errors = predictions[:, 0] - labels[:, 0]
    return authenticity_errors

def get_rmse(errors: torch.Tensor) -> torch.Tensor:
    """
    Get the root mean squared error.

    Args:
        errors (torch.Tensor): Errors.

    Returns:
        torch.Tensor: Root mean squared error.
    """
    return torch.sqrt(torch.mean(errors ** 2))

# %% [markdown]
# ## Training section

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Data transformations for the ImageNet dataset
data_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

annotations_file = 'Dataset/AIGCIQA2023/mos_data.csv'

# Create the dataset
dataset = ImageAuthenticityDataset(csv_file=annotations_file, transform=data_transforms)

# Set random seeds for reproducibility
torch.manual_seed(42)
torch.cuda.manual_seed(42)
np.random.seed(42)

# Split the dataset into training, validation, and test sets
train_size = int(0.7 * len(dataset))
val_size = int(0.2 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])


# Create data loaders
BATCH_SIZE = 64
EPOCHS = 20
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
val_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

# Create a dictionary containing the data loaders
dataloaders = {
    'train': train_dataloader,
    'val': val_dataloader,
    'test': test_dataloader
}

model = AuthenticityPredictor()
criterion = nn.MSELoss()  # Mean Squared Error Loss (regression)
optimizer = optim.Adam(model.regression_head.parameters(), lr=0.001)

model_path = 'Models/VGG-16_authenticity_finetuned.pth'

# %% [markdown]
# ## Train

# %%
authenticity_predictor_trained= train_model(model, dataloaders, criterion, optimizer, EPOCHS, device)

# Save the trained model
torch.save(authenticity_predictor_trained.state_dict(), "Models/VGG-16_authenticity_finetuned.pth")
# Out:
# Epoch 0/19
# ----------
# train phase
# train Loss: 777.7876
# val phase
# val Loss: 134.2582
# Epoch 1/19
# ----------
# train phase
# train Loss: 206.4005
# val phase
# val Loss: 196.0453
# Epoch 2/19
# ----------
# train phase
# train Loss: 161.9668
# val phase
# val Loss: 193.4858
# Epoch 3/19
# ----------
# train phase
# train Loss: 149.4155
# val phase
# val Loss: 183.4053
# Epoch 4/19
# ----------
# train phase
# train Loss: 146.0410
# val phase
# val Loss: 156.5203
# Epoch 5/19
# ----------
# train phase
# train Loss: 141.8292
# val phase
# val Loss: 167.9337
# Epoch 6/19
# ----------
# train phase
# train Loss: 131.4791
# val phase
# val Loss: 165.7670
# Epoch 7/19
# ----------
# train phase
# train Loss: 133.6336
# val phase
# val Loss: 164.5004
# Epoch 8/19
# ----------
# train phase
# train Loss: 138.0414
# val phase
# val Loss: 160.4423
# Epoch 9/19
# ----------
# train phase
# train Loss: 128.6270
# val phase
# val Loss: 158.1449
# Epoch 10/19
# ----------
# train phase
# train Loss: 130.6597
# val phase
# val Loss: 149.2516
# Epoch 11/19
# ----------
# train phase
# train Loss: 123.8050
# val phase
# val Loss: 139.9666
# Epoch 12/19
# ----------
# train phase
# train Loss: 119.6514
# val phase
# val Loss: 154.5075
# Epoch 13/19
# ----------
# train phase
# train Loss: 123.5701
# val phase
# val Loss: 157.3159
# Epoch 14/19
# ----------
# train phase
# train Loss: 122.4083
# val phase
# val Loss: 155.9101
# Epoch 15/19
# ----------
# train phase
# train Loss: 123.9496
# val phase
# val Loss: 129.7109
# Epoch 16/19
# ----------
# train phase
# train Loss: 118.2568
# val phase
# val Loss: 154.2517
# Epoch 17/19
# ----------
# train phase
# train Loss: 124.0761
# val phase
# val Loss: 143.9720
# Epoch 18/19
# ----------
# train phase
# train Loss: 128.3869
# val phase
# val Loss: 138.7855
# Epoch 19/19
# ----------
# train phase
# train Loss: 115.6857
# val phase
# val Loss: 142.4547
# Finished Training

# %% [markdown]
# ## Utilities for pruning

# %%
def compute_feature_map_importance(model, dataloader, device, layer_name) -> tuple[np.ndarray, np.ndarray]:
    """Computes the importance of each feature map in a convolution
    layer by measuring the change in predictions when the feature map is zero
    out.
    
    Returns:
        tuple: (indices, importance_scores) where both are numpy arrays
    """
    #if importance_scores.npy exists, load it
    if os.path.exists('Ranking_arrays/authenticity_importance_scores.npy'):
        print("Importance scores already computed, loading from file")
        return np.load('Ranking_arrays/authenticity_importance_scores.npy')
    
    model.eval()
    model.to(device)
    importance_scores = []
    dict_modules = dict(model.named_modules())
    layer = dict_modules[layer_name]
    baseline_predictions = get_predictions(model, dataloader, device)
    regression_errors = get_regression_errors(baseline_predictions)
    baseline_authenticity_rmse = get_rmse(regression_errors)

    
    print(f'Authenticity baseline RMSE: {baseline_authenticity_rmse:.4f}')

    with torch.no_grad():
        for i in range(layer.out_channels):
            # Create a backup of the weights and bias
            backup_weights = layer.weight[i, ...].clone()
            backup_bias = layer.bias[i].clone() if layer.bias is not None else None

            # Zero out the i-th output channel
            layer.weight[i, ...] = 0
            if layer.bias is not None:
                layer.bias[i] = 0

            # Get predictions with the pruned feature map
            pruned_predictions = get_predictions(model, dataloader, device)
            pruned_regression_errors = get_regression_errors(pruned_predictions)
            pruned_authenticity_rmse = get_rmse(pruned_regression_errors)
            
    
            # Compute importance score
            importance_score = baseline_authenticity_rmse - pruned_authenticity_rmse
            importance_scores.append([i, importance_score])
            

            print(f'Feature map {i}: Importance score: {importance_score:.4f}')
            
            # After computing importance, restore weights and bias
            layer.weight[i, ...] = backup_weights
            if layer.bias is not None:
                layer.bias[i] = backup_bias 

    sorted_importance_scores = sorted(importance_scores, key=lambda x: x[1], reverse=True)
    # save np array 
    np.save('authenticity_importance_scores.np', sorted_importance_scores)
    return np.array(sorted_importance_scores)

def remove_noisy_feature_maps(model, dataloader, device, layer_name, sorted_importance_scores, model_path='Models/pruned_model.pth'):
    """
    Remove noisy feature maps from a convolutional layer based on importance scores.
    Feature maps are zeroed out one by one and kept zeroed only if model performance improves.
    
    Args:
        model: The neural network model
        dataloader: DataLoader for evaluation
        device: Device to run the model on (cuda/cpu)
        layer_name: Name of the layer to optimize
        sorted_importance_scores: List of tuples (channel_index, importance_score) sorted by importance
        
    Returns:
        Dictionary with pruning results and performance metrics
    """
    model.eval()
    model.to(device)
    
    # Get the target layer
    dict_modules = dict(model.named_modules())
    layer = dict_modules[layer_name]
    
    # Create a backup of the original weights and bias
    original_weights = layer.weight.clone()
    original_bias = layer.bias.clone() if layer.bias is not None else None
    
    # Initialize tracking variables
    removed_features = []
    rmse_history = []
    
    # Get baseline performance
    baseline_predictions = get_predictions(model, dataloader, device)
    baseline_regression_errors = get_regression_errors(baseline_predictions)
    baseline_authenticity_rmse = get_rmse(baseline_regression_errors)
    
    
    print(f"Baseline authenticity RMSE: {baseline_authenticity_rmse:.4f}")
    print("------------------")
    
    # Track initial performance
    rmse_history.append(([], baseline_authenticity_rmse))
    baseline_rmse = baseline_authenticity_rmse
    
    # Iterate over the sorted indices and if removing a feature map improves performance, keep it removed
    for idx, (channel_idx, importance_score) in enumerate(sorted_importance_scores):
        channel_idx = int(channel_idx)
        
        # Temporarily zero out this feature map
        layer.weight[channel_idx, ...] = 0
        if layer.bias is not None:
            layer.bias[channel_idx] = 0
        
        # Evaluate model with feature map removed
        predictions = get_predictions(model, dataloader, device)
        regression_errors = get_regression_errors(predictions)
        authenticity_pruned_rmse = get_rmse(regression_errors)
        
        print(f"Iteration {idx+1}/{len(sorted_importance_scores)}: " +
              f"Testing removal of channel {channel_idx}, " +
              f"Importance: {importance_score:.4f}, " +
              f"RMSE: {authenticity_pruned_rmse:.4f}")
        
        # Decide whether to keep this feature map removed
        if authenticity_pruned_rmse < baseline_rmse:
            baseline_rmse = authenticity_pruned_rmse # Update baseline RMSE
            removed_features.append(channel_idx)
            rmse_history.append((removed_features.copy(), baseline_rmse))
            print(f"  ✓ IMPROVING: Zeroing out feature map {channel_idx}")
        else:
            # Restore the feature map
            layer.weight[channel_idx, ...] = original_weights[channel_idx, ...]
            if layer.bias is not None:
                layer.bias[channel_idx] = original_bias[channel_idx]
            print(f"  ✗ NOT IMPROVING: Keeping feature map {channel_idx}")
        
        print(f"  Current best RMSE: {baseline_rmse:.4f}")
        print("------------------")
    
    # Final statistics
    print("\n------------------")
    print(f"Final RMSE: {baseline_rmse:.4f} after removing {len(removed_features)} feature maps")
    print(f"Improvement over baseline: {baseline_authenticity_rmse - baseline_rmse:.4f}")
    print(f"Feature reduction: {(len(removed_features)/len(sorted_importance_scores))*100:.1f}%")
    
    # Save the pruned model
    torch.save(model.state_dict(), model_path)
    
    return {
        'removed_features': removed_features,
        'baseline_rmse': baseline_authenticity_rmse,
        'final_rmse': baseline_rmse,
        'improvement': baseline_authenticity_rmse - baseline_rmse,
        'reduction_percentage': (len(removed_features)/len(sorted_importance_scores))*100,
        'rmse_history': rmse_history
    }

def remove_negative_impact_feature_maps(model, dataloader, device, layer_name, sorted_importance_scores, model_path='Models/negative_impact_pruned_model.pth'):
    """
    Remove feature maps that have a negative impact on model performance based on importance scores (impotance score > 0).
    
    Args:
        model: The neural network model
        dataloader: DataLoader for evaluation
        device: Device to run the model on (cuda/cpu)
        layer_name: Name of the layer to optimize
        sorted_importance_scores: List of tuples (channel_index, importance_score) sorted by importance
        
    Returns:
        Dictionary with pruning results and performance metrics
    """
    model.eval()
    model.to(device)
    
    # Get the target layer
    dict_modules = dict(model.named_modules())
    layer = dict_modules[layer_name]
    
    # Create a backup of the original weights and bias
    original_weights = layer.weight.clone()
    original_bias = layer.bias.clone() if layer.bias is not None else None
    
    # Get baseline performance
    predictions = get_predictions(model, dataloader, device)
    regression_errors = get_regression_errors(predictions)
    authenticity_rmse = get_rmse(regression_errors)

    # Initialize tracking variables
    removed_features = []
    
    # Iterate over the sorted indices and zero out all the feature maps that have a negative impact (importance < 0)

    for idx, (channel_idx, importance_score) in enumerate(sorted_importance_scores):
        print(f"Iteration {idx} - Channel {channel_idx}: Importance score: {importance_score:.4f}")
        if importance_score > 0:
            channel_idx = int(channel_idx)
            layer.weight[channel_idx, ...] = 0
            if layer.bias is not None:
                layer.bias[channel_idx] = 0
            removed_features.append(channel_idx)

    # Evaluate model with feature maps removed
    new_predictions = get_predictions(model, dataloader, device)
    new_regression_errors = get_regression_errors(new_predictions)
    new_authenticity_rmse = get_rmse(new_regression_errors)

    # Save the pruned model
    torch.save(model.state_dict(), model_path)

    # Restore original weights for future use
    layer.weight.data.copy_(original_weights)
    if layer.bias is not None:
        layer.bias.data.copy_(original_bias)

    
    return {
        'removed_features': removed_features,
        'baseline_rmse': authenticity_rmse,
        'final_rmse': new_authenticity_rmse,
        'improvement': authenticity_rmse - new_authenticity_rmse,
        'reduction_percentage': (len(removed_features)/len(sorted_importance_scores))*100
    }

def remove_channels(model,device,layer_name,channels_indexes)->AuthenticityPredictor:
    """
    Remove channels, using an index list, from a convolutional layer in a model.
    
    Args:
        model: The neural network model
        device: Device to run the model on (cuda/cpu)
        layer_name: Name of the layer to optimize
        channels_indexes: List of channel indexes to remove
        
    Returns:
        The pruned model
    """
    model.eval()
    model.to(device)
    
    # Get the target layer
    dict_modules = dict(model.named_modules())
    layer = dict_modules[layer_name]
        
    # Zero out the specified channels
    for channel_idx in channels_indexes:
        layer.weight[channel_idx, ...] = 0
        if layer.bias is not None:
            layer.bias[channel_idx] = 0
    
    return model

# %% [markdown]
# # Creation of diffrent models using different pruning techniques
#
# - Deletion of models is due to make sure that im not using the same model again and again (first draft, not sure if im correctlly restoring weights in each pruning technique)

# %%
# LAYER to prune
LAYER = 'features.28'
DEVICE = 'cuda'

# Base model for importance score computation
base_model = AuthenticityPredictor()
base_model.load_state_dict(torch.load('Models/VGG-16_authenticity_finetuned.pth'))
base_model.eval()
base_model.to(DEVICE)

sorted_importance_scores = compute_feature_map_importance(base_model, train_dataloader, DEVICE, LAYER)
np.save('Ranking_arrays/authenticity_importance_scores.npy', sorted_importance_scores)
del base_model

# Model for negative impact feature maps removal
negative_impact_model = AuthenticityPredictor()
negative_impact_model.load_state_dict(torch.load('Models/VGG-16_authenticity_finetuned.pth'))
negative_impact_model.eval()
negative_impact_model.to(DEVICE)

negative_impact_subset = remove_negative_impact_feature_maps(negative_impact_model, train_dataloader, DEVICE, LAYER, sorted_importance_scores, model_path='Models/authenticity_negative_impact_pruned_model.pth')

del negative_impact_model


# Model for noisy feature maps removal
noisy_pruning_model = AuthenticityPredictor()
noisy_pruning_model.load_state_dict(torch.load('Models/VGG-16_authenticity_finetuned.pth'))
noisy_pruning_model.eval()
noisy_pruning_model.to(DEVICE)

noisy_optimal_subset = remove_noisy_feature_maps(noisy_pruning_model, train_dataloader, DEVICE, LAYER, sorted_importance_scores, model_path='Models/authenticity_noise_out_pruned_model.pth')

del noisy_pruning_model
# Out:
# /tmp/ipykernel_1099599/762001622.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   base_model.load_state_dict(torch.load('Models/VGG-16_authenticity_finetuned.pth'))
# Importance scores already computed, loading from file
# /tmp/ipykernel_1099599/762001622.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   negative_impact_model.load_state_dict(torch.load('Models/VGG-16_authenticity_finetuned.pth'))
# Iteration 495 - Channel 42.0: Importance score: -0.3770
# Iteration 496 - Channel 225.0: Importance score: -0.3907
# Iteration 497 - Channel 279.0: Importance score: -0.3911
# Iteration 498 - Channel 23.0: Importance score: -0.3942
# Iteration 499 - Channel 63.0: Importance score: -0.4214
# Iteration 500 - Channel 397.0: Importance score: -0.4322
# Iteration 501 - Channel 206.0: Importance score: -0.4505
# Iteration 502 - Channel 117.0: Importance score: -0.4516
# Iteration 503 - Channel 119.0: Importance score: -0.4541
# Iteration 504 - Channel 439.0: Importance score: -0.5652
# Iteration 505 - Channel 291.0: Importance score: -0.5719
# Iteration 506 - Channel 135.0: Importance score: -0.5728
# Iteration 507 - Channel 210.0: Importance score: -0.6974
# Iteration 508 - Channel 468.0: Importance score: -0.8291
# Iteration 509 - Channel 479.0: Importance score: -0.9092
# Iteration 510 - Channel 450.0: Importance score: -0.9879
# Iteration 511 - Channel 444.0: Importance score: -1.0290
# /tmp/ipykernel_1099599/762001622.py:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   noisy_pruning_model.load_state_dict(torch.load('Models/VGG-16_authenticity_finetuned.pth'))
# Baseline authenticity RMSE: 11.0042
# ------------------
# Iteration 1/512: Testing removal of channel 497, Importance: 0.4390, RMSE: 10.5652
#   ✓ IMPROVING: Zeroing out feature map 497
#   Current best RMSE: 10.5652
# ------------------
# Iteration 2/512: Testing removal of channel 423, Importance: 0.1793, RMSE: 10.3927
#   ✓ IMPROVING: Zeroing out feature map 423
#   Current best RMSE: 10.3927
# ------------------
# Iteration 3/512: Testing removal of channel 86, Importance: 0.1675, RMSE: 10.2352
#   ✓ IMPROVING: Zeroing out feature map 86
#   Current best RMSE: 10.2352
# ------------------
# Iteration 4/512: Testing removal of channel 458, Importance: 0.1653, RMSE: 10.0939
#   ✓ IMPROVING: Zeroing out feature map 458
#   Current best RMSE: 10.0939
# ------------------
# Iteration 5/512: Testing removal of channel 262, Importance: 0.1554, RMSE: 9.9633
#   ✓ IMPROVING: Zeroing out feature map 262
#   Current best RMSE: 9.9633
# ------------------
# Iteration 6/512: Testing removal of channel 113, Importance: 0.1458, RMSE: 9.8384
#   ✓ IMPROVING: Zeroing out feature map 113
#   Current best RMSE: 9.8384
# ------------------
# Iteration 7/512: Testing removal of channel 236, Importance: 0.1354, RMSE: 9.7304
#   ✓ IMPROVING: Zeroing out feature map 236
#   Current best RMSE: 9.7304
# ------------------
# Iteration 8/512: Testing removal of channel 47, Importance: 0.1319, RMSE: 9.6336
#   ✓ IMPROVING: Zeroing out feature map 47
#   Current best RMSE: 9.6336
# ------------------
# Iteration 9/512: Testing removal of channel 303, Importance: 0.1291, RMSE: 9.5172
#   ✓ IMPROVING: Zeroing out feature map 303
#   Current best RMSE: 9.5172
# ------------------
# Iteration 10/512: Testing removal of channel 165, Importance: 0.1185, RMSE: 9.4118
#   ✓ IMPROVING: Zeroing out feature map 165
#   Current best RMSE: 9.4118
# ------------------
# Iteration 11/512: Testing removal of channel 234, Importance: 0.1174, RMSE: 9.3126
#   ✓ IMPROVING: Zeroing out feature map 234
#   Current best RMSE: 9.3126
# ------------------
# Iteration 12/512: Testing removal of channel 137, Importance: 0.1090, RMSE: 9.2433
#   ✓ IMPROVING: Zeroing out feature map 137
#   Current best RMSE: 9.2433
# ------------------
# Iteration 13/512: Testing removal of channel 175, Importance: 0.1079, RMSE: 9.1755
#   ✓ IMPROVING: Zeroing out feature map 175
#   Current best RMSE: 9.1755
# ------------------
# Iteration 14/512: Testing removal of channel 224, Importance: 0.1063, RMSE: 9.0953
#   ✓ IMPROVING: Zeroing out feature map 224
#   Current best RMSE: 9.0953
# ------------------
# Iteration 15/512: Testing removal of channel 261, Importance: 0.1062, RMSE: 9.0364
#   ✓ IMPROVING: Zeroing out feature map 261
#   Current best RMSE: 9.0364
# ------------------
# Iteration 16/512: Testing removal of channel 326, Importance: 0.1037, RMSE: 8.9543
#   ✓ IMPROVING: Zeroing out feature map 326
#   Current best RMSE: 8.9543
# ------------------
# Iteration 17/512: Testing removal of channel 384, Importance: 0.0995, RMSE: 8.8710
#   ✓ IMPROVING: Zeroing out feature map 384
#   Current best RMSE: 8.8710
# ------------------
# Iteration 18/512: Testing removal of channel 213, Importance: 0.0984, RMSE: 8.8097
#   ✓ IMPROVING: Zeroing out feature map 213
#   Current best RMSE: 8.8097
# ------------------
# Iteration 19/512: Testing removal of channel 287, Importance: 0.0966, RMSE: 8.7568
#   ✓ IMPROVING: Zeroing out feature map 287
#   Current best RMSE: 8.7568
# ------------------
# Iteration 20/512: Testing removal of channel 99, Importance: 0.0964, RMSE: 8.6978
#   ✓ IMPROVING: Zeroing out feature map 99
#   Current best RMSE: 8.6978
# ------------------
# Iteration 21/512: Testing removal of channel 344, Importance: 0.0931, RMSE: 8.6443
#   ✓ IMPROVING: Zeroing out feature map 344
#   Current best RMSE: 8.6443
# ------------------
# Iteration 22/512: Testing removal of channel 180, Importance: 0.0897, RMSE: 8.5706
#   ✓ IMPROVING: Zeroing out feature map 180
#   Current best RMSE: 8.5706
# ------------------
# Iteration 23/512: Testing removal of channel 55, Importance: 0.0879, RMSE: 8.5446
#   ✓ IMPROVING: Zeroing out feature map 55
#   Current best RMSE: 8.5446
# ------------------
# Iteration 24/512: Testing removal of channel 202, Importance: 0.0873, RMSE: 8.4865
#   ✓ IMPROVING: Zeroing out feature map 202
#   Current best RMSE: 8.4865
# ------------------
# Iteration 25/512: Testing removal of channel 79, Importance: 0.0861, RMSE: 8.4433
#   ✓ IMPROVING: Zeroing out feature map 79
#   Current best RMSE: 8.4433
# ------------------
# Iteration 26/512: Testing removal of channel 183, Importance: 0.0841, RMSE: 8.4000
#   ✓ IMPROVING: Zeroing out feature map 183
#   Current best RMSE: 8.4000
# ------------------
# Iteration 27/512: Testing removal of channel 263, Importance: 0.0837, RMSE: 8.3524
#   ✓ IMPROVING: Zeroing out feature map 263
#   Current best RMSE: 8.3524
# ------------------
# Iteration 28/512: Testing removal of channel 404, Importance: 0.0837, RMSE: 8.3162
#   ✓ IMPROVING: Zeroing out feature map 404
#   Current best RMSE: 8.3162
# ------------------
# Iteration 29/512: Testing removal of channel 51, Importance: 0.0836, RMSE: 8.3042
#   ✓ IMPROVING: Zeroing out feature map 51
#   Current best RMSE: 8.3042
# ------------------
# Iteration 30/512: Testing removal of channel 147, Importance: 0.0750, RMSE: 8.2686
#   ✓ IMPROVING: Zeroing out feature map 147
#   Current best RMSE: 8.2686
# ------------------
# Iteration 31/512: Testing removal of channel 343, Importance: 0.0743, RMSE: 8.2255
#   ✓ IMPROVING: Zeroing out feature map 343
#   Current best RMSE: 8.2255
# ------------------
# Iteration 32/512: Testing removal of channel 340, Importance: 0.0739, RMSE: 8.1928
#   ✓ IMPROVING: Zeroing out feature map 340
#   Current best RMSE: 8.1928
# ------------------
# Iteration 33/512: Testing removal of channel 237, Importance: 0.0729, RMSE: 8.1574
#   ✓ IMPROVING: Zeroing out feature map 237
#   Current best RMSE: 8.1574
# ------------------
# Iteration 34/512: Testing removal of channel 265, Importance: 0.0712, RMSE: 8.1131
#   ✓ IMPROVING: Zeroing out feature map 265
#   Current best RMSE: 8.1131
# ------------------
# Iteration 35/512: Testing removal of channel 510, Importance: 0.0707, RMSE: 8.0793
#   ✓ IMPROVING: Zeroing out feature map 510
#   Current best RMSE: 8.0793
# ------------------
# Iteration 36/512: Testing removal of channel 375, Importance: 0.0703, RMSE: 8.0303
#   ✓ IMPROVING: Zeroing out feature map 375
#   Current best RMSE: 8.0303
# ------------------
# Iteration 37/512: Testing removal of channel 290, Importance: 0.0701, RMSE: 8.0160
#   ✓ IMPROVING: Zeroing out feature map 290
#   Current best RMSE: 8.0160
# ------------------
# Iteration 38/512: Testing removal of channel 94, Importance: 0.0674, RMSE: 8.0358
#   ✗ NOT IMPROVING: Keeping feature map 94
#   Current best RMSE: 8.0160
# ------------------
# Iteration 39/512: Testing removal of channel 300, Importance: 0.0674, RMSE: 7.9698
#   ✓ IMPROVING: Zeroing out feature map 300
#   Current best RMSE: 7.9698
# ------------------
# Iteration 40/512: Testing removal of channel 478, Importance: 0.0670, RMSE: 7.9645
#   ✓ IMPROVING: Zeroing out feature map 478
#   Current best RMSE: 7.9645
# ------------------
# Iteration 41/512: Testing removal of channel 255, Importance: 0.0640, RMSE: 7.9457
#   ✓ IMPROVING: Zeroing out feature map 255
#   Current best RMSE: 7.9457
# ------------------
# Iteration 42/512: Testing removal of channel 251, Importance: 0.0635, RMSE: 7.9135
#   ✓ IMPROVING: Zeroing out feature map 251
#   Current best RMSE: 7.9135
# ------------------
# Iteration 43/512: Testing removal of channel 62, Importance: 0.0631, RMSE: 7.9229
#   ✗ NOT IMPROVING: Keeping feature map 62
#   Current best RMSE: 7.9135
# ------------------
# Iteration 44/512: Testing removal of channel 447, Importance: 0.0627, RMSE: 7.8900
#   ✓ IMPROVING: Zeroing out feature map 447
#   Current best RMSE: 7.8900
# ------------------
# Iteration 45/512: Testing removal of channel 144, Importance: 0.0621, RMSE: 7.8714
#   ✓ IMPROVING: Zeroing out feature map 144
#   Current best RMSE: 7.8714
# ------------------
# Iteration 46/512: Testing removal of channel 174, Importance: 0.0602, RMSE: 7.8773
#   ✗ NOT IMPROVING: Keeping feature map 174
#   Current best RMSE: 7.8714
# ------------------
# Iteration 47/512: Testing removal of channel 321, Importance: 0.0580, RMSE: 7.8696
#   ✓ IMPROVING: Zeroing out feature map 321
#   Current best RMSE: 7.8696
# ------------------
# Iteration 48/512: Testing removal of channel 14, Importance: 0.0572, RMSE: 7.8626
#   ✓ IMPROVING: Zeroing out feature map 14
#   Current best RMSE: 7.8626
# ------------------
# Iteration 49/512: Testing removal of channel 250, Importance: 0.0568, RMSE: 7.8477
#   ✓ IMPROVING: Zeroing out feature map 250
#   Current best RMSE: 7.8477
# ------------------
# Iteration 50/512: Testing removal of channel 432, Importance: 0.0540, RMSE: 7.8487
#   ✗ NOT IMPROVING: Keeping feature map 432
#   Current best RMSE: 7.8477
# ------------------
# Iteration 51/512: Testing removal of channel 76, Importance: 0.0535, RMSE: 7.8318
#   ✓ IMPROVING: Zeroing out feature map 76
#   Current best RMSE: 7.8318
# ------------------
# Iteration 52/512: Testing removal of channel 323, Importance: 0.0528, RMSE: 7.8003
#   ✓ IMPROVING: Zeroing out feature map 323
#   Current best RMSE: 7.8003
# ------------------
# Iteration 53/512: Testing removal of channel 40, Importance: 0.0525, RMSE: 7.7786
#   ✓ IMPROVING: Zeroing out feature map 40
#   Current best RMSE: 7.7786
# ------------------
# Iteration 54/512: Testing removal of channel 481, Importance: 0.0524, RMSE: 7.7765
#   ✓ IMPROVING: Zeroing out feature map 481
#   Current best RMSE: 7.7765
# ------------------
# Iteration 55/512: Testing removal of channel 214, Importance: 0.0522, RMSE: 7.7485
#   ✓ IMPROVING: Zeroing out feature map 214
#   Current best RMSE: 7.7485
# ------------------
# Iteration 56/512: Testing removal of channel 428, Importance: 0.0514, RMSE: 7.7670
#   ✗ NOT IMPROVING: Keeping feature map 428
#   Current best RMSE: 7.7485
# ------------------
# Iteration 57/512: Testing removal of channel 29, Importance: 0.0509, RMSE: 7.7446
#   ✓ IMPROVING: Zeroing out feature map 29
#   Current best RMSE: 7.7446
# ------------------
# Iteration 58/512: Testing removal of channel 417, Importance: 0.0503, RMSE: 7.7418
#   ✓ IMPROVING: Zeroing out feature map 417
#   Current best RMSE: 7.7418
# ------------------
# Iteration 59/512: Testing removal of channel 484, Importance: 0.0502, RMSE: 7.7500
#   ✗ NOT IMPROVING: Keeping feature map 484
#   Current best RMSE: 7.7418
# ------------------
# Iteration 60/512: Testing removal of channel 34, Importance: 0.0499, RMSE: 7.7323
#   ✓ IMPROVING: Zeroing out feature map 34
#   Current best RMSE: 7.7323
# ------------------
# Iteration 61/512: Testing removal of channel 92, Importance: 0.0497, RMSE: 7.7389
#   ✗ NOT IMPROVING: Keeping feature map 92
#   Current best RMSE: 7.7323
# ------------------
# Iteration 62/512: Testing removal of channel 302, Importance: 0.0495, RMSE: 7.7297
#   ✓ IMPROVING: Zeroing out feature map 302
#   Current best RMSE: 7.7297
# ------------------
# Iteration 63/512: Testing removal of channel 437, Importance: 0.0488, RMSE: 7.7253
#   ✓ IMPROVING: Zeroing out feature map 437
#   Current best RMSE: 7.7253
# ------------------
# Iteration 64/512: Testing removal of channel 3, Importance: 0.0486, RMSE: 7.7252
#   ✓ IMPROVING: Zeroing out feature map 3
#   Current best RMSE: 7.7252
# ------------------
# Iteration 65/512: Testing removal of channel 177, Importance: 0.0486, RMSE: 7.7342
#   ✗ NOT IMPROVING: Keeping feature map 177
#   Current best RMSE: 7.7252
# ------------------
# Iteration 66/512: Testing removal of channel 501, Importance: 0.0484, RMSE: 7.7337
#   ✗ NOT IMPROVING: Keeping feature map 501
#   Current best RMSE: 7.7252
# ------------------
# Iteration 67/512: Testing removal of channel 401, Importance: 0.0479, RMSE: 7.7232
#   ✓ IMPROVING: Zeroing out feature map 401
#   Current best RMSE: 7.7232
# ------------------
# Iteration 68/512: Testing removal of channel 73, Importance: 0.0479, RMSE: 7.7410
#   ✗ NOT IMPROVING: Keeping feature map 73
#   Current best RMSE: 7.7232
# ------------------
# Iteration 69/512: Testing removal of channel 164, Importance: 0.0475, RMSE: 7.7253
#   ✗ NOT IMPROVING: Keeping feature map 164
#   Current best RMSE: 7.7232
# ------------------
# Iteration 70/512: Testing removal of channel 448, Importance: 0.0474, RMSE: 7.7227
#   ✓ IMPROVING: Zeroing out feature map 448
#   Current best RMSE: 7.7227
# ------------------
# Iteration 71/512: Testing removal of channel 307, Importance: 0.0451, RMSE: 7.7401
#   ✗ NOT IMPROVING: Keeping feature map 307
#   Current best RMSE: 7.7227
# ------------------
# Iteration 72/512: Testing removal of channel 239, Importance: 0.0442, RMSE: 7.7238
#   ✗ NOT IMPROVING: Keeping feature map 239
#   Current best RMSE: 7.7227
# ------------------
# Iteration 73/512: Testing removal of channel 124, Importance: 0.0440, RMSE: 7.7199
#   ✓ IMPROVING: Zeroing out feature map 124
#   Current best RMSE: 7.7199
# ------------------
# Iteration 74/512: Testing removal of channel 110, Importance: 0.0439, RMSE: 7.7198
#   ✓ IMPROVING: Zeroing out feature map 110
#   Current best RMSE: 7.7198
# ------------------
# Iteration 75/512: Testing removal of channel 157, Importance: 0.0423, RMSE: 7.7613
#   ✗ NOT IMPROVING: Keeping feature map 157
#   Current best RMSE: 7.7198
# ------------------
# Iteration 76/512: Testing removal of channel 223, Importance: 0.0416, RMSE: 7.7474
#   ✗ NOT IMPROVING: Keeping feature map 223
#   Current best RMSE: 7.7198
# ------------------
# Iteration 77/512: Testing removal of channel 4, Importance: 0.0415, RMSE: 7.7173
#   ✓ IMPROVING: Zeroing out feature map 4
#   Current best RMSE: 7.7173
# ------------------
# Iteration 78/512: Testing removal of channel 438, Importance: 0.0411, RMSE: 7.7297
#   ✗ NOT IMPROVING: Keeping feature map 438
#   Current best RMSE: 7.7173
# ------------------
# Iteration 79/512: Testing removal of channel 368, Importance: 0.0408, RMSE: 7.7258
#   ✗ NOT IMPROVING: Keeping feature map 368
#   Current best RMSE: 7.7173
# ------------------
# Iteration 80/512: Testing removal of channel 396, Importance: 0.0407, RMSE: 7.7296
#   ✗ NOT IMPROVING: Keeping feature map 396
#   Current best RMSE: 7.7173
# ------------------
# Iteration 81/512: Testing removal of channel 184, Importance: 0.0403, RMSE: 7.7238
#   ✗ NOT IMPROVING: Keeping feature map 184
#   Current best RMSE: 7.7173
# ------------------
# Iteration 82/512: Testing removal of channel 220, Importance: 0.0398, RMSE: 7.7190
#   ✗ NOT IMPROVING: Keeping feature map 220
#   Current best RMSE: 7.7173
# ------------------
# Iteration 83/512: Testing removal of channel 205, Importance: 0.0393, RMSE: 7.7220
#   ✗ NOT IMPROVING: Keeping feature map 205
#   Current best RMSE: 7.7173
# ------------------
# Iteration 84/512: Testing removal of channel 310, Importance: 0.0392, RMSE: 7.7409
#   ✗ NOT IMPROVING: Keeping feature map 310
#   Current best RMSE: 7.7173
# ------------------
# Iteration 85/512: Testing removal of channel 136, Importance: 0.0392, RMSE: 7.7172
#   ✓ IMPROVING: Zeroing out feature map 136
#   Current best RMSE: 7.7172
# ------------------
# Iteration 86/512: Testing removal of channel 209, Importance: 0.0390, RMSE: 7.7422
#   ✗ NOT IMPROVING: Keeping feature map 209
#   Current best RMSE: 7.7172
# ------------------
# Iteration 87/512: Testing removal of channel 59, Importance: 0.0380, RMSE: 7.7518
#   ✗ NOT IMPROVING: Keeping feature map 59
#   Current best RMSE: 7.7172
# ------------------
# Iteration 88/512: Testing removal of channel 43, Importance: 0.0376, RMSE: 7.7231
#   ✗ NOT IMPROVING: Keeping feature map 43
#   Current best RMSE: 7.7172
# ------------------
# Iteration 89/512: Testing removal of channel 9, Importance: 0.0375, RMSE: 7.7241
#   ✗ NOT IMPROVING: Keeping feature map 9
#   Current best RMSE: 7.7172
# ------------------
# Iteration 90/512: Testing removal of channel 421, Importance: 0.0369, RMSE: 7.7399
#   ✗ NOT IMPROVING: Keeping feature map 421
#   Current best RMSE: 7.7172
# ------------------
# Iteration 91/512: Testing removal of channel 489, Importance: 0.0365, RMSE: 7.7234
#   ✗ NOT IMPROVING: Keeping feature map 489
#   Current best RMSE: 7.7172
# ------------------
# Iteration 92/512: Testing removal of channel 324, Importance: 0.0359, RMSE: 7.7350
#   ✗ NOT IMPROVING: Keeping feature map 324
#   Current best RMSE: 7.7172
# ------------------
# Iteration 93/512: Testing removal of channel 13, Importance: 0.0352, RMSE: 7.7157
#   ✓ IMPROVING: Zeroing out feature map 13
#   Current best RMSE: 7.7157
# ------------------
# ...
#   ✗ NOT IMPROVING: Keeping feature map 75
#   Current best RMSE: 7.4530
# ------------------
# Iteration 423/512: Testing removal of channel 18, Importance: -0.1176, RMSE: 7.4842
#   ✗ NOT IMPROVING: Keeping feature map 18
#   Current best RMSE: 7.4530
# ------------------
# Iteration 424/512: Testing removal of channel 241, Importance: -0.1177, RMSE: 7.5012
#   ✗ NOT IMPROVING: Keeping feature map 241
#   Current best RMSE: 7.4530
# ------------------
# Iteration 425/512: Testing removal of channel 0, Importance: -0.1180, RMSE: 7.5055
#   ✗ NOT IMPROVING: Keeping feature map 0
#   Current best RMSE: 7.4530
# ------------------
# Iteration 426/512: Testing removal of channel 41, Importance: -0.1185, RMSE: 7.4625
#   ✗ NOT IMPROVING: Keeping feature map 41
#   Current best RMSE: 7.4530
# ------------------
# Iteration 427/512: Testing removal of channel 337, Importance: -0.1195, RMSE: 7.5302
#   ✗ NOT IMPROVING: Keeping feature map 337
#   Current best RMSE: 7.4530
# ------------------
# Iteration 428/512: Testing removal of channel 108, Importance: -0.1218, RMSE: 7.4809
#   ✗ NOT IMPROVING: Keeping feature map 108
#   Current best RMSE: 7.4530
# ------------------
# Iteration 429/512: Testing removal of channel 370, Importance: -0.1231, RMSE: 7.4809
#   ✗ NOT IMPROVING: Keeping feature map 370
#   Current best RMSE: 7.4530
# ------------------
# Iteration 430/512: Testing removal of channel 359, Importance: -0.1237, RMSE: 7.4681
#   ✗ NOT IMPROVING: Keeping feature map 359
#   Current best RMSE: 7.4530
# ------------------
# Iteration 431/512: Testing removal of channel 471, Importance: -0.1257, RMSE: 7.5088
#   ✗ NOT IMPROVING: Keeping feature map 471
#   Current best RMSE: 7.4530
# ------------------
# Iteration 432/512: Testing removal of channel 78, Importance: -0.1261, RMSE: 7.4787
#   ✗ NOT IMPROVING: Keeping feature map 78
#   Current best RMSE: 7.4530
# ------------------
# Iteration 433/512: Testing removal of channel 57, Importance: -0.1264, RMSE: 7.5050
#   ✗ NOT IMPROVING: Keeping feature map 57
#   Current best RMSE: 7.4530
# ------------------
# Iteration 434/512: Testing removal of channel 199, Importance: -0.1301, RMSE: 7.5229
#   ✗ NOT IMPROVING: Keeping feature map 199
#   Current best RMSE: 7.4530
# ------------------
# Iteration 435/512: Testing removal of channel 172, Importance: -0.1304, RMSE: 7.5202
#   ✗ NOT IMPROVING: Keeping feature map 172
#   Current best RMSE: 7.4530
# ------------------
# Iteration 436/512: Testing removal of channel 354, Importance: -0.1317, RMSE: 7.4926
#   ✗ NOT IMPROVING: Keeping feature map 354
#   Current best RMSE: 7.4530
# ------------------
# Iteration 437/512: Testing removal of channel 295, Importance: -0.1319, RMSE: 7.5159
#   ✗ NOT IMPROVING: Keeping feature map 295
#   Current best RMSE: 7.4530
# ------------------
# Iteration 438/512: Testing removal of channel 160, Importance: -0.1332, RMSE: 7.5276
#   ✗ NOT IMPROVING: Keeping feature map 160
#   Current best RMSE: 7.4530
# ------------------
# Iteration 439/512: Testing removal of channel 410, Importance: -0.1341, RMSE: 7.5075
#   ✗ NOT IMPROVING: Keeping feature map 410
#   Current best RMSE: 7.4530
# ------------------
# Iteration 440/512: Testing removal of channel 431, Importance: -0.1348, RMSE: 7.4673
#   ✗ NOT IMPROVING: Keeping feature map 431
#   Current best RMSE: 7.4530
# ------------------
# Iteration 441/512: Testing removal of channel 122, Importance: -0.1359, RMSE: 7.4787
#   ✗ NOT IMPROVING: Keeping feature map 122
#   Current best RMSE: 7.4530
# ------------------
# Iteration 442/512: Testing removal of channel 20, Importance: -0.1383, RMSE: 7.5300
#   ✗ NOT IMPROVING: Keeping feature map 20
#   Current best RMSE: 7.4530
# ------------------
# Iteration 443/512: Testing removal of channel 316, Importance: -0.1386, RMSE: 7.5227
#   ✗ NOT IMPROVING: Keeping feature map 316
#   Current best RMSE: 7.4530
# ------------------
# Iteration 444/512: Testing removal of channel 72, Importance: -0.1386, RMSE: 7.5024
#   ✗ NOT IMPROVING: Keeping feature map 72
#   Current best RMSE: 7.4530
# ------------------
# Iteration 445/512: Testing removal of channel 133, Importance: -0.1398, RMSE: 7.4572
#   ✗ NOT IMPROVING: Keeping feature map 133
#   Current best RMSE: 7.4530
# ------------------
# Iteration 446/512: Testing removal of channel 181, Importance: -0.1448, RMSE: 7.4820
#   ✗ NOT IMPROVING: Keeping feature map 181
#   Current best RMSE: 7.4530
# ------------------
# Iteration 447/512: Testing removal of channel 440, Importance: -0.1471, RMSE: 7.4960
#   ✗ NOT IMPROVING: Keeping feature map 440
#   Current best RMSE: 7.4530
# ------------------
# Iteration 448/512: Testing removal of channel 12, Importance: -0.1486, RMSE: 7.4593
#   ✗ NOT IMPROVING: Keeping feature map 12
#   Current best RMSE: 7.4530
# ------------------
# Iteration 449/512: Testing removal of channel 170, Importance: -0.1524, RMSE: 7.5421
#   ✗ NOT IMPROVING: Keeping feature map 170
#   Current best RMSE: 7.4530
# ------------------
# Iteration 450/512: Testing removal of channel 409, Importance: -0.1537, RMSE: 7.5066
#   ✗ NOT IMPROVING: Keeping feature map 409
#   Current best RMSE: 7.4530
# ------------------
# Iteration 451/512: Testing removal of channel 351, Importance: -0.1576, RMSE: 7.5486
#   ✗ NOT IMPROVING: Keeping feature map 351
#   Current best RMSE: 7.4530
# ------------------
# Iteration 452/512: Testing removal of channel 195, Importance: -0.1606, RMSE: 7.4929
#   ✗ NOT IMPROVING: Keeping feature map 195
#   Current best RMSE: 7.4530
# ------------------
# Iteration 453/512: Testing removal of channel 103, Importance: -0.1623, RMSE: 7.5067
#   ✗ NOT IMPROVING: Keeping feature map 103
#   Current best RMSE: 7.4530
# ------------------
# Iteration 454/512: Testing removal of channel 503, Importance: -0.1625, RMSE: 7.5020
#   ✗ NOT IMPROVING: Keeping feature map 503
#   Current best RMSE: 7.4530
# ------------------
# Iteration 455/512: Testing removal of channel 252, Importance: -0.1652, RMSE: 7.5046
#   ✗ NOT IMPROVING: Keeping feature map 252
#   Current best RMSE: 7.4530
# ------------------
# Iteration 456/512: Testing removal of channel 132, Importance: -0.1659, RMSE: 7.5084
#   ✗ NOT IMPROVING: Keeping feature map 132
#   Current best RMSE: 7.4530
# ------------------
# Iteration 457/512: Testing removal of channel 66, Importance: -0.1673, RMSE: 7.4820
#   ✗ NOT IMPROVING: Keeping feature map 66
#   Current best RMSE: 7.4530
# ------------------
# Iteration 458/512: Testing removal of channel 339, Importance: -0.1717, RMSE: 7.5285
#   ✗ NOT IMPROVING: Keeping feature map 339
#   Current best RMSE: 7.4530
# ------------------
# Iteration 459/512: Testing removal of channel 127, Importance: -0.1746, RMSE: 7.4889
#   ✗ NOT IMPROVING: Keeping feature map 127
#   Current best RMSE: 7.4530
# ------------------
# Iteration 460/512: Testing removal of channel 53, Importance: -0.1749, RMSE: 7.5268
#   ✗ NOT IMPROVING: Keeping feature map 53
#   Current best RMSE: 7.4530
# ------------------
# Iteration 461/512: Testing removal of channel 366, Importance: -0.1776, RMSE: 7.5134
#   ✗ NOT IMPROVING: Keeping feature map 366
#   Current best RMSE: 7.4530
# ------------------
# Iteration 462/512: Testing removal of channel 286, Importance: -0.1783, RMSE: 7.5077
#   ✗ NOT IMPROVING: Keeping feature map 286
#   Current best RMSE: 7.4530
# ------------------
# Iteration 463/512: Testing removal of channel 167, Importance: -0.1793, RMSE: 7.5134
#   ✗ NOT IMPROVING: Keeping feature map 167
#   Current best RMSE: 7.4530
# ------------------
# Iteration 464/512: Testing removal of channel 71, Importance: -0.1805, RMSE: 7.5359
#   ✗ NOT IMPROVING: Keeping feature map 71
#   Current best RMSE: 7.4530
# ------------------
# Iteration 465/512: Testing removal of channel 272, Importance: -0.1845, RMSE: 7.5212
#   ✗ NOT IMPROVING: Keeping feature map 272
#   Current best RMSE: 7.4530
# ------------------
# Iteration 466/512: Testing removal of channel 412, Importance: -0.1927, RMSE: 7.5145
#   ✗ NOT IMPROVING: Keeping feature map 412
#   Current best RMSE: 7.4530
# ------------------
# Iteration 467/512: Testing removal of channel 114, Importance: -0.1970, RMSE: 7.5044
#   ✗ NOT IMPROVING: Keeping feature map 114
#   Current best RMSE: 7.4530
# ------------------
# Iteration 468/512: Testing removal of channel 118, Importance: -0.2019, RMSE: 7.5355
#   ✗ NOT IMPROVING: Keeping feature map 118
#   Current best RMSE: 7.4530
# ------------------
# Iteration 469/512: Testing removal of channel 419, Importance: -0.2028, RMSE: 7.5644
#   ✗ NOT IMPROVING: Keeping feature map 419
#   Current best RMSE: 7.4530
# ------------------
# Iteration 470/512: Testing removal of channel 365, Importance: -0.2032, RMSE: 7.5009
#   ✗ NOT IMPROVING: Keeping feature map 365
#   Current best RMSE: 7.4530
# ------------------
# Iteration 471/512: Testing removal of channel 342, Importance: -0.2052, RMSE: 7.5183
#   ✗ NOT IMPROVING: Keeping feature map 342
#   Current best RMSE: 7.4530
# ------------------
# Iteration 472/512: Testing removal of channel 37, Importance: -0.2076, RMSE: 7.5257
#   ✗ NOT IMPROVING: Keeping feature map 37
#   Current best RMSE: 7.4530
# ------------------
# Iteration 473/512: Testing removal of channel 491, Importance: -0.2209, RMSE: 7.5376
#   ✗ NOT IMPROVING: Keeping feature map 491
#   Current best RMSE: 7.4530
# ------------------
# Iteration 474/512: Testing removal of channel 348, Importance: -0.2213, RMSE: 7.5223
#   ✗ NOT IMPROVING: Keeping feature map 348
#   Current best RMSE: 7.4530
# ------------------
# Iteration 475/512: Testing removal of channel 158, Importance: -0.2230, RMSE: 7.4604
#   ✗ NOT IMPROVING: Keeping feature map 158
#   Current best RMSE: 7.4530
# ------------------
# Iteration 476/512: Testing removal of channel 84, Importance: -0.2264, RMSE: 7.4675
#   ✗ NOT IMPROVING: Keeping feature map 84
#   Current best RMSE: 7.4530
# ------------------
# Iteration 477/512: Testing removal of channel 465, Importance: -0.2324, RMSE: 7.5305
#   ✗ NOT IMPROVING: Keeping feature map 465
#   Current best RMSE: 7.4530
# ------------------
# Iteration 478/512: Testing removal of channel 38, Importance: -0.2363, RMSE: 7.5256
#   ✗ NOT IMPROVING: Keeping feature map 38
#   Current best RMSE: 7.4530
# ------------------
# Iteration 479/512: Testing removal of channel 363, Importance: -0.2373, RMSE: 7.5731
#   ✗ NOT IMPROVING: Keeping feature map 363
#   Current best RMSE: 7.4530
# ------------------
# Iteration 480/512: Testing removal of channel 179, Importance: -0.2383, RMSE: 7.5322
#   ✗ NOT IMPROVING: Keeping feature map 179
#   Current best RMSE: 7.4530
# ------------------
# Iteration 481/512: Testing removal of channel 355, Importance: -0.2427, RMSE: 7.5784
#   ✗ NOT IMPROVING: Keeping feature map 355
#   Current best RMSE: 7.4530
# ------------------
# Iteration 482/512: Testing removal of channel 379, Importance: -0.2457, RMSE: 7.4772
#   ✗ NOT IMPROVING: Keeping feature map 379
#   Current best RMSE: 7.4530
# ------------------
# Iteration 483/512: Testing removal of channel 253, Importance: -0.2527, RMSE: 7.6148
#   ✗ NOT IMPROVING: Keeping feature map 253
#   Current best RMSE: 7.4530
# ------------------
# Iteration 484/512: Testing removal of channel 97, Importance: -0.2626, RMSE: 7.5487
#   ✗ NOT IMPROVING: Keeping feature map 97
#   Current best RMSE: 7.4530
# ------------------
# Iteration 485/512: Testing removal of channel 298, Importance: -0.2639, RMSE: 7.5821
#   ✗ NOT IMPROVING: Keeping feature map 298
#   Current best RMSE: 7.4530
# ------------------
# Iteration 486/512: Testing removal of channel 194, Importance: -0.2680, RMSE: 7.5151
#   ✗ NOT IMPROVING: Keeping feature map 194
#   Current best RMSE: 7.4530
# ------------------
# Iteration 487/512: Testing removal of channel 208, Importance: -0.2737, RMSE: 7.5968
#   ✗ NOT IMPROVING: Keeping feature map 208
#   Current best RMSE: 7.4530
# ------------------
# Iteration 488/512: Testing removal of channel 502, Importance: -0.2837, RMSE: 7.5203
#   ✗ NOT IMPROVING: Keeping feature map 502
#   Current best RMSE: 7.4530
# ------------------
# Iteration 489/512: Testing removal of channel 232, Importance: -0.2927, RMSE: 7.5739
#   ✗ NOT IMPROVING: Keeping feature map 232
#   Current best RMSE: 7.4530
# ------------------
# Iteration 490/512: Testing removal of channel 462, Importance: -0.3110, RMSE: 7.5529
#   ✗ NOT IMPROVING: Keeping feature map 462
#   Current best RMSE: 7.4530
# ------------------
# Iteration 491/512: Testing removal of channel 171, Importance: -0.3151, RMSE: 7.5713
#   ✗ NOT IMPROVING: Keeping feature map 171
#   Current best RMSE: 7.4530
# ------------------
# Iteration 492/512: Testing removal of channel 11, Importance: -0.3179, RMSE: 7.5805
#   ✗ NOT IMPROVING: Keeping feature map 11
#   Current best RMSE: 7.4530
# ------------------
# Iteration 493/512: Testing removal of channel 82, Importance: -0.3233, RMSE: 7.5566
#   ✗ NOT IMPROVING: Keeping feature map 82
#   Current best RMSE: 7.4530
# ------------------
# Iteration 494/512: Testing removal of channel 372, Importance: -0.3628, RMSE: 7.6127
#   ✗ NOT IMPROVING: Keeping feature map 372
#   Current best RMSE: 7.4530
# ------------------
# Iteration 495/512: Testing removal of channel 33, Importance: -0.3737, RMSE: 7.5928
#   ✗ NOT IMPROVING: Keeping feature map 33
#   Current best RMSE: 7.4530
# ------------------
# Iteration 496/512: Testing removal of channel 42, Importance: -0.3770, RMSE: 7.5730
#   ✗ NOT IMPROVING: Keeping feature map 42
#   Current best RMSE: 7.4530
# ------------------
# Iteration 497/512: Testing removal of channel 225, Importance: -0.3907, RMSE: 7.6164
#   ✗ NOT IMPROVING: Keeping feature map 225
#   Current best RMSE: 7.4530
# ------------------
# Iteration 498/512: Testing removal of channel 279, Importance: -0.3911, RMSE: 7.5480
#   ✗ NOT IMPROVING: Keeping feature map 279
#   Current best RMSE: 7.4530
# ------------------
# Iteration 499/512: Testing removal of channel 23, Importance: -0.3942, RMSE: 7.6601
#   ✗ NOT IMPROVING: Keeping feature map 23
#   Current best RMSE: 7.4530
# ------------------
# Iteration 500/512: Testing removal of channel 63, Importance: -0.4214, RMSE: 7.7196
#   ✗ NOT IMPROVING: Keeping feature map 63
#   Current best RMSE: 7.4530
# ------------------
# Iteration 501/512: Testing removal of channel 397, Importance: -0.4322, RMSE: 7.6037
#   ✗ NOT IMPROVING: Keeping feature map 397
#   Current best RMSE: 7.4530
# ------------------
# Iteration 502/512: Testing removal of channel 206, Importance: -0.4505, RMSE: 7.6217
#   ✗ NOT IMPROVING: Keeping feature map 206
#   Current best RMSE: 7.4530
# ------------------
# Iteration 503/512: Testing removal of channel 117, Importance: -0.4516, RMSE: 7.6351
#   ✗ NOT IMPROVING: Keeping feature map 117
#   Current best RMSE: 7.4530
# ------------------
# Iteration 504/512: Testing removal of channel 119, Importance: -0.4541, RMSE: 7.5856
#   ✗ NOT IMPROVING: Keeping feature map 119
#   Current best RMSE: 7.4530
# ------------------
# Iteration 505/512: Testing removal of channel 439, Importance: -0.5652, RMSE: 7.7453
#   ✗ NOT IMPROVING: Keeping feature map 439
#   Current best RMSE: 7.4530
# ------------------
# Iteration 506/512: Testing removal of channel 291, Importance: -0.5719, RMSE: 7.7078
#   ✗ NOT IMPROVING: Keeping feature map 291
#   Current best RMSE: 7.4530
# ------------------
# Iteration 507/512: Testing removal of channel 135, Importance: -0.5728, RMSE: 7.6084
#   ✗ NOT IMPROVING: Keeping feature map 135
#   Current best RMSE: 7.4530
# ------------------
# Iteration 508/512: Testing removal of channel 210, Importance: -0.6974, RMSE: 7.6753
#   ✗ NOT IMPROVING: Keeping feature map 210
#   Current best RMSE: 7.4530
# ------------------
# Iteration 509/512: Testing removal of channel 468, Importance: -0.8291, RMSE: 7.9163
#   ✗ NOT IMPROVING: Keeping feature map 468
#   Current best RMSE: 7.4530
# ------------------
# Iteration 510/512: Testing removal of channel 479, Importance: -0.9092, RMSE: 7.9668
#   ✗ NOT IMPROVING: Keeping feature map 479
#   Current best RMSE: 7.4530
# ------------------
# Iteration 511/512: Testing removal of channel 450, Importance: -0.9879, RMSE: 7.8645
#   ✗ NOT IMPROVING: Keeping feature map 450
#   Current best RMSE: 7.4530
# ------------------
# Iteration 512/512: Testing removal of channel 444, Importance: -1.0290, RMSE: 8.0253
#   ✗ NOT IMPROVING: Keeping feature map 444
#   Current best RMSE: 7.4530
# ------------------
#
# ------------------
# Final RMSE: 7.4530 after removing 117 feature maps
# Improvement over baseline: 3.5512
# Feature reduction: 22.9%

# %% [markdown]
# # Testing with already saved weights

# %%
BASE_MODEL = 'Models/VGG-16_authenticity_finetuned.pth'
NEGATIVE_IMPACT_PRUNED_MODEL_PATH = 'Models/authenticity_negative_impact_pruned_model.pth'

base_model = AuthenticityPredictor()
base_model.load_state_dict(torch.load(BASE_MODEL, weights_only=True))

negative_impact_pruned_model = AuthenticityPredictor()
negative_impact_pruned_model.load_state_dict(torch.load(NEGATIVE_IMPACT_PRUNED_MODEL_PATH,weights_only=True))

noisy_optimal_subset = AuthenticityPredictor()
noisy_optimal_subset.load_state_dict(torch.load('Models/authenticity_noise_out_pruned_model.pth',weights_only=True))
# Testing

# Test the baseline model
print("Testing the baseline model")
test_model(base_model, test_dataloader, criterion, device)
print("------------------")

# test the negative impact pruned model
print("Testing the negative impact pruned model")
test_model(negative_impact_pruned_model, test_dataloader, criterion, device)
print("------------------")

# test the noisy optimal subset pruned model
print("Testing the noisy optimal subset pruned model")
test_model(noisy_optimal_subset, test_dataloader, criterion, device)
print("------------------")
# Out:
# Testing the baseline model
# Test Loss: 152.4362
# ------------------
# Testing the negative impact pruned model
# Test Loss: 120.3955
# ------------------
# Testing the noisy optimal subset pruned model
# Test Loss: 90.7545
# ------------------

# %% [markdown]
# # Final Aanalysis - Comparing the models zeroed out weights & Correlations between the models predicitons and ground truth

# %% [markdown]
# ## Zero-out weights analysis

# %%
# Create a function that extract the indices of the zeroed out feature maps in a convolutional layer

def get_zeroed_feature_maps(model, layer_name):
    """
    Get the indices of the zeroed out feature maps in a convolutional layer.

    Args:
        model (nn.Module): The neural network model.
        layer_name (str): The name of the convolutional layer.

    Returns:
        list: The indices of the zeroed out feature maps.
    """
    dict_modules = dict(model.named_modules())
    layer = dict_modules[layer_name]
    zeroed_feature_maps = []

    for i, weight in enumerate(layer.weight):
        if torch.all(weight == 0):
            zeroed_feature_maps.append(i)
    zeroed_feature_maps.sort()

    num_zeroed = len(zeroed_feature_maps)

    return zeroed_feature_maps, num_zeroed

# Get the zeroed out feature maps in the 'features.28' layer of the noisy pruned model
_, noisy_num_zeroed = get_zeroed_feature_maps(noisy_pruned_model, 'features.28')

# Get the zeroed out feature maps in the 'features.28' layer of the best subset pruned model
_, best_subset_num_zeroed = get_zeroed_feature_maps(best_subset_pruned_model, 'features.28')

# Get the zeroed out feature maps in the 'features.28' layer of the negative impact pruned model
_, negative_impact_num_zeroed = get_zeroed_feature_maps(negative_impact_pruned_model, 'features.28')

print(f"Noisy pruned model: {noisy_num_zeroed} zeroed out feature maps")
print(f"Best subset pruned model: {best_subset_num_zeroed} zeroed out feature maps")
print(f"Negative impact pruned model: {negative_impact_num_zeroed} zeroed out feature maps")

# %% [markdown]
# # Test RSA on the models (baseline and pruned models)

# %% [markdown]
# ### Definition of the models for RSA

# %%
BASELINE_MODEL_NAME = 'Models/VGG-16_authenticity_finetuned.pth'
NOISY_PRUNED_MODEL_PATH = 'Models/authenticity_noise_out_pruned_model.pth'
NEGATIVE_IMPACT_PRUNED_MODEL_PATH = 'Models/authenticity_negative_impact_pruned_model.pth'

baseline_model = AuthenticityPredictor()
baseline_model.load_state_dict(torch.load(BASELINE_MODEL_NAME, weights_only=True))

noisy_pruned_model = AuthenticityPredictor()
noisy_pruned_model.load_state_dict(torch.load(NOISY_PRUNED_MODEL_PATH, weights_only=True))

negative_impact_pruned_model = AuthenticityPredictor()
negative_impact_pruned_model.load_state_dict(torch.load(NEGATIVE_IMPACT_PRUNED_MODEL_PATH,weights_only=True))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Helper functions for RSA

# %%
from scipy.stats import spearmanr
from sklearn.metrics.pairwise import cosine_similarity

# %%
class FeatureMapHook:
    """Hook to extract feature maps from neural network layers."""
    
    def __init__(self):
        self.feature_maps = []
    
    def __call__(self, module, input, output):
        # Detach from computation graph and move to CPU
        self.feature_maps.append(output.detach().cpu())

def get_feature_maps(model, dataloader, layer_name, device):
    """
    Extracts the feature maps of a specific layer from a model.
    
    Args:
        model (nn.Module): The neural network model.
        dataloader (DataLoader): DataLoader for evaluation.
        layer_name (str): The name of the layer to extract feature maps from.
        device (str): Device to run the model on ('cuda' or 'cpu').
        
    Returns:
        np.ndarray: The feature maps as a numpy array with shape (240, num_features).
    """
    # Set model to evaluation mode
    model.eval()
    model.to(device)
    
    # Register a hook to extract feature maps
    hook = FeatureMapHook()
    target_layer = dict(model.named_modules())[layer_name]
    hook_handle = target_layer.register_forward_hook(hook)
    
    # Forward pass to extract feature maps from the dataloader
    with torch.no_grad():
        for inputs, _ in dataloader:
            inputs = inputs.to(device)
            model(inputs)

    # Remove the hook
    hook_handle.remove()
    
    # Process the feature maps to get the desired shape
    all_features = []
    
    for batch_features in hook.feature_maps:
        # Handle different possible output formats (accommodate different layer types)
        if len(batch_features.shape) == 4:  # Conv layers: [batch_size, channels, height, width]
            batch_size, channels, height, width = batch_features.shape
            # Flatten spatial dimensions and create one feature vector per sample
            batch_features = batch_features.reshape(batch_size, channels * height * width)
        elif len(batch_features.shape) == 2:  # Linear layers: [batch_size, features]
            pass  # Already in the right format
        
        # Add batch features to our collection
        all_features.append(batch_features)
    
    # Concatenate all batches and convert to numpy
    features_tensor = torch.cat(all_features, dim=0)
    
    # Ensure we have exactly the number of samples we expect in the dataloader 
    assert features_tensor.shape[0] == len(dataloader.dataset) 
    
    # Convert to numpy array
    features_array = features_tensor.numpy()
    
    return features_array
def compute_similarity_matrix(features):
    """
    Compute a similarity matrix from feature embeddings.
    Works with both convolutional features (4D) and FC features (2D).
    
    Args:
        features: numpy array - either shape (n_samples, n_channels, height, width)
                 or shape (n_samples, n_features)
        
    Returns:
        similarity_matrix: numpy array of shape (n_samples, n_samples)
    """
    # Check the dimensionality of features
    n_samples = features.shape[0]
    
    # If features are from convolutional layer (4D), reshape to 2D
    if len(features.shape) == 4:
        features_flat = features.reshape(n_samples, -1)
    else:
        # Features are already 2D (from FC layer)
        features_flat = features
    
    # Compute cosine similarity between all pairs
    similarity_matrix = cosine_similarity(features_flat)
    
    return similarity_matrix

def compute_quality_difference_matrix(quality_scores):
    """
    Compute a matrix of quality differences between all pairs of samples.
    
    Args:
        quality_scores: numpy array of shape (n_samples,) containing quality scores
        
    Returns:
        difference_matrix: numpy array of shape (n_samples, n_samples)
    """
    n_samples = quality_scores.shape[0]
    difference_matrix = np.zeros((n_samples, n_samples))
    
    # Compute absolute differences between all pairs
    for i in range(n_samples):
        for j in range(n_samples):
            difference_matrix[i, j] = abs(quality_scores[i] - quality_scores[j])
            
    return difference_matrix

def get_upper_triangle(matrix):
    """
    Extract the upper triangle of a matrix (excluding diagonal).
    
    Args:
        matrix: numpy array of shape (n, n)
        
    Returns:
        upper_triangle: flattened upper triangle values
    """
    indices = np.triu_indices_from(matrix, k=1)
    return matrix[indices]

def calculate_fit(similarity_matrix, quality_diff_matrix):
    """
    Calculate the fit between similarity and quality difference matrices.
    
    Args:
        similarity_matrix: numpy array of shape (n_samples, n_samples)
        quality_diff_matrix: numpy array of shape (n_samples, n_samples)
        
    Returns:
        correlation: Spearman correlation coefficient between the matrices
        p_value: p-value of the correlation
    """
    # Extract upper triangles (excluding diagonal)
    sim_upper = get_upper_triangle(similarity_matrix)
    qual_upper = get_upper_triangle(quality_diff_matrix)
    
    # Compute correlation (negative since higher similarity should correspond to lower difference)
    correlation, p_value = spearmanr(sim_upper, qual_upper)
    
    # We're expecting a negative correlation (higher similarity → lower quality difference)
    # so we return the negative correlation value for easier interpretation
    return -correlation, p_value

# %%
# Get feature maps
baseline_features = get_feature_maps(baseline_model, test_dataloader, 'fc1.3', device)

noisy_pruned_features = get_feature_maps(noisy_pruned_model, test_dataloader, 'fc1.3', device)

negative_impact_features = get_feature_maps(negative_impact_pruned_model, test_dataloader, 'fc1.3', device)

# Extract quality scores
auth_scores_list = []
with torch.no_grad():
	for _, labels in test_dataloader:
		auth_scores_list.append(labels[:, 0])  # First column contains auth scores
q_scores = torch.cat(auth_scores_list).numpy()

# %%
# Compute similarity matrices
baseline_similarity = compute_similarity_matrix(baseline_features)
noisy_similarity = compute_similarity_matrix(noisy_pruned_features)
negative_impact_similarity = compute_similarity_matrix(negative_impact_features)

# Compute quality difference matrices
quality_diff_matrix = compute_quality_difference_matrix(q_scores)

# Calculate fit between similarity and quality difference matrices
baseline_fit = calculate_fit(baseline_similarity, quality_diff_matrix)
noisy_fit = calculate_fit(noisy_similarity, quality_diff_matrix)
negative_impact_fit = calculate_fit(negative_impact_similarity, quality_diff_matrix)

print("Baseline Model Fit:")
print(f"Correlation: {baseline_fit[0]:.4f}")
print("------------------")
print("RSME Noise-out Pruned Model Fit:")
print(f"Correlation: {noisy_fit[0]:.4f}")
print("------------------")
print("RSME Negative Impact Pruned Model Fit:")
print(f"Correlation: {negative_impact_fit[0]:.4f}")
# Out:
# Baseline Model Fit:
# Correlation: 0.0139
# ------------------
# RSME Noise-out Pruned Model Fit:
# Correlation: 0.0070
# ------------------
# RSME Negative Impact Pruned Model Fit:
# Correlation: 0.0141
