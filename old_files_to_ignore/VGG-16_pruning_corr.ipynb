# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torchvision.models import vgg16, VGG16_Weights
from torch.utils.data import Dataset, DataLoader, random_split
import pandas as pd
from PIL import Image
import os
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import numpy as np
from scipy.stats import spearmanr

# %%
class ImageQualityDataset(Dataset):
    """Dataset for image quality assessment."""

    def __init__(self, csv_file, transform=None):
        """
        Args:
            csv_file (string): Path to the CSV file with annotations.
            transform (callable, optional): Optional transform to be applied on a sample.
        """
        self.data = pd.read_csv(csv_file)
        self.transform = transform

    def __len__(self):
        """Returns the number of samples in the dataset."""
        return len(self.data)

    def __getitem__(self, idx):
        """
        Retrieves an image and its labels by index.

        Args:
            idx (int): Index of the sample to retrieve.

        Returns:
            tuple: A tuple (image, labels) where:
                image (PIL.Image): The image.
                labels (torch.Tensor): Tensor containing quality and authenticity scores.
        """
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_name = os.path.join(os.getcwd(), self.data.iloc[idx, 3])  # image_path column
        image = Image.open(img_name).convert('RGB')
        quality = self.data.iloc[idx, 0]  # Quality column
        authenticity = self.data.iloc[idx, 1]  # Authenticity column
        labels = torch.tensor([quality, authenticity], dtype=torch.float)


        if self.transform:
            image = self.transform(image)

        return image, labels

# %%
class VGG16(nn.Module):
    """VGG16 model for image quality assessment."""

    def __init__(self, num_outputs=2):
        """
        Initializes the VGG16 model.

        Args:
            num_outputs (int): Number of output features. Defaults to 2 (quality and authenticity).
        """
        super(VGG16, self).__init__()
        # Load pre-trained VGG16 model
        self.vgg16 = models.vgg16(weights=VGG16_Weights.DEFAULT)

        # Freeze all layers
        for param in self.vgg16.parameters():
            param.requires_grad = False

        # Modify the classifier
        num_features = self.vgg16.classifier[6].in_features
        self.vgg16.classifier = nn.Sequential(
            *list(self.vgg16.classifier.children())[:-1],  # Remove last layer with 1000 outputs
            nn.Linear(num_features, 128),
            nn.ReLU(inplace=True),
            nn.Linear(128, num_outputs)  # Add new layer with num_out outputs
        )

    def forward(self, x):
        """
        Forward pass of the model.

        Args:
            x (torch.Tensor): Input tensor.

        Returns:
            torch.Tensor: Output tensor.
        """
        return self.vgg16(x)
    
class QualityPredictor(nn.Module):
    def __init__(self, freeze_backbone=True):
        super().__init__()
        # Load pre-trained VGG16
        vgg = vgg16(weights=VGG16_Weights.DEFAULT)
        
        # Freeze backbone if requested
        if freeze_backbone:
            for param in vgg.features.parameters():
                param.requires_grad = False
                
        # Extract features up to fc2
        self.features = vgg.features
        self.avgpool = vgg.avgpool
        self.fc1 = vgg.classifier[:-1]  # Up to fc2 (4096 -> 128)
        
        # New regression head
        self.regression_head = nn.Sequential(
            nn.Linear(4096, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, 2)  # Predict quality and realness
        )
        
    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        features = self.fc1(x)
        predictions = self.regression_head(features)
        return predictions, features

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=10, device='cuda'):
    """
    Trains the model.

    Args:
        model (nn.Module): The model to train.
        dataloaders (dict): A dictionary containing the training and validation data loaders.
        criterion (nn.Module): The loss function.
        optimizer (optim.Optimizer): The optimizer.
        num_epochs (int): Number of epochs to train for. Defaults to 10.
        device (str): Device to use for training ('cuda' or 'cpu'). Defaults to 'cuda'.

    Returns:
        nn.Module: The trained model.
    """
    model.to(device)
    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        for phase in ['train', 'val']:  # Iterate over training and validation phases
            print(f'{phase} phase')
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0

            for inputs, labels in dataloaders[phase]:  # Iterate over data in the current phase
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):  # Enable gradients only during training
                    outputs, _ = model(inputs)
                    loss = criterion(outputs, labels)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)

            print(f'{phase} Loss: {epoch_loss:.4f}') # Print loss for the current phase

    print("Finished Training")
    return model

def test_model(model, dataloader, criterion, device='cuda'):

    """
    Tests the model on the test dataset.

    Args:
        model (nn.Module): The trained model.
        dataloader (DataLoader): The test data loader.
        criterion (nn.Module): The loss function.
        device (str): Device to use for testing ('cuda' or 'cpu'). Defaults to 'cuda'.

    Returns:
        float: The average loss on the test dataset.
    """
    model.eval()  # Set the model to evaluation mode
    model.to(device)
    running_loss = 0.0

    with torch.no_grad():  # Disable gradient calculation
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs, _ = model(inputs)
            
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)

    test_loss = running_loss / len(dataloader.dataset)
    print(f'Test Loss: {test_loss:.4f}')
    return test_loss

def get_predictions(model, dataloader, device)-> tuple[torch.Tensor, torch.Tensor]:
    """
    Get predictions from the model.

    Args:
        model (nn.Module): The trained model.
        dataloader (DataLoader): The data loader.

    Returns:
        tuple: A tuple (predictions, labels) where:
            predictions (torch.Tensor): Predictions from the model.
            labels (torch.Tensor): Ground truth labels.
    """
    model.eval()  # Set the model to evaluation mode
    model.to(device)
    predictions = []
    labels = []

    with torch.no_grad():  # Disable gradient calculation
        for inputs, target in dataloader:
            outputs, _ = model(inputs.to(device))
            predictions.append(outputs)
            labels.append(target)

    #move to cpu and concatenate
    predictions = torch.cat(predictions).cpu()
    labels = torch.cat(labels).cpu()

    return predictions, labels

def evaluate_predictions(predictions: torch.Tensor, labels: torch.Tensor)-> dict:
    """
    Calculate the Spearman correlation coefficient between predictions and labels. 
    Args:
        predictions (torch.Tensor): Predictions from the model.
        labels (torch.Tensor): Ground truth labels.
    Returns:
        dict: Dictionary containing the quality_corr, authenticity_corr, quality_rmse, and authenticity_rm
    """
    # Ensure tensors are on CPU and convert to numpy
    if torch.is_tensor(predictions):
        predictions = predictions.cpu().numpy()
    if torch.is_tensor(labels):
        labels = labels.cpu().numpy()

    quality_corr, _ = spearmanr(predictions[:, 0], labels[:, 0])
    authenticity_corr, _ = spearmanr(predictions[:, 1], labels[:, 1])

    quality_rmse = np.sqrt(np.mean((predictions[:, 0] - labels[:, 0]) ** 2))
    authenticity_rmse = np.sqrt(np.mean((predictions[:, 1] - labels[:, 1]) ** 2))

    return {'quality_corr': quality_corr, 'authenticity_corr': authenticity_corr, 'quality_rmse': quality_rmse, 'authenticity_rmse': authenticity_rmse}

# %% [markdown]
# ## Training section

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Data transformations for the ImageNet dataset
data_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

annotations_file = 'Dataset/AIGCIQA2023/mos_data.csv'

# Create the dataset
dataset = ImageQualityDataset(csv_file=annotations_file, transform=data_transforms)

# Split the dataset into training, validation, and test sets
train_size = int(0.7 * len(dataset))
val_size = int(0.2 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

print(f'Training samples: {len(train_dataset)}')
print(f'Validation samples: {len(val_dataset)}')
print(f'Test samples: {len(test_dataset)}')

# Create data loaders
batch_size = 64
epochs = 20
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)

# Create a dictionary containing the data loaders
dataloaders = {
    'train': train_dataloader,
    'val': val_dataloader,
    'test': test_dataloader
}

# Model initialization for prediction of quality and authenticity (2 outputs)
#model = QualityPredictor()

# Loss function and optimizer
criterion = nn.MSELoss()  # Mean Squared Error Loss (regression)
# optimizer = optim.Adam(model.regression_head.parameters(), lr=0.001)

# Define the model path
model_path = 'Weights/VGG-16_finetuned_regression.pth'

# quality_predictor_trained= train_model(model, dataloaders, criterion, optimizer, epochs, device)

# # Save the trained model
# torch.save(quality_predictor_trained.state_dict(), model_path)

# Load the trained model
# quality_predictor_trained = QualityPredictor()
# quality_predictor_trained.load_state_dict(torch.load(model_path))
# Out:
# Training samples: 1680
# Validation samples: 480
# Test samples: 240

# %% [markdown]
# ## Utilities for pruning

# %%
def compute_feature_map_importance(model, dataloader, device, layer_name) -> tuple[np.ndarray, np.ndarray]:
    """Computes the importance of each feature map in a convolution
    layer by measuring the change in predictions when the feature map is zero
    out.
    
    Returns:
        tuple: (indices, importance_scores) where both are numpy arrays
    """
    #if importance_scores.npy exists, load it
    if os.path.exists('delta_correlation_scores.npy'):
        return np.load('delta_correlation_scores.npy')
    
    model.eval()
    model.to(device)
    delta_corr_scores = []
    dict_modules = dict(model.named_modules())
    layer = dict_modules[layer_name]

    # Get baseline predictions
    baseline_predictions = get_predictions(model, dataloader, device)
   
    baseline_results = evaluate_predictions(baseline_predictions[0], baseline_predictions[1])

    baseline_quality_corr = baseline_results['quality_corr']
    
    with torch.no_grad():
        for i in range(layer.out_channels):
            # Create a backup of the weights and bias
            backup_weights = layer.weight[i, ...].clone()
            backup_bias = layer.bias[i].clone() if layer.bias is not None else None

            # Zero out the i-th output channel
            layer.weight[i, ...] = 0
            if layer.bias is not None:
                layer.bias[i] = 0

            # Get predictions with the pruned model
            pruned_predictions = get_predictions(model, dataloader, device)
            pruned_results = evaluate_predictions(pruned_predictions[0], pruned_predictions[1])
            pruned_quality_corr = pruned_results['quality_corr']
            
            # Compute importance score as the change in correlation
            delta_corr = pruned_quality_corr - baseline_quality_corr
            delta_corr_scores.append((i, delta_corr))

            print('Baseline Quality Correlation:', baseline_quality_corr)
            print('Pruned Quality Correlation:', pruned_quality_corr)
            print(f'Feature map {i}: Change in correlation: {delta_corr:.4f}')
            print('------------------')
            # After computing importance, restore weights and bias
            layer.weight[i, ...] = backup_weights
            if layer.bias is not None:
                layer.bias[i] = backup_bias 

    sorted_delta_corr_scores = sorted(delta_corr_scores, key=lambda x: x[1], reverse=True)
    # save np array 
    np.save('delta_quality_correlation_scores.npy', sorted_delta_corr_scores)
    return np.array(sorted_delta_corr_scores)

def remove_noisy_feature_maps(model, dataloader, device, layer_name, sorted_importance_scores, model_path='Weights/pruned_model.pth'):
    """
    Remove noisy feature maps from a convolutional layer based on importance scores.
    Feature maps are zeroed out one by one and kept zeroed only if model performance improves.
    
    Args:
        model: The neural network model
        dataloader: DataLoader for evaluation
        device: Device to run the model on (cuda/cpu)
        layer_name: Name of the layer to optimize
        sorted_importance_scores: List of tuples (channel_index, importance_score) sorted by importance
        
    Returns:
        Dictionary with pruning results and performance metrics
    """
    model.eval()
    model.to(device)
    
    # Get the target layer
    dict_modules = dict(model.named_modules())
    layer = dict_modules[layer_name]
    
    # Create a backup of the original weights and bias
    original_weights = layer.weight.clone()
    original_bias = layer.bias.clone() if layer.bias is not None else None
    
    # Initialize tracking variables
    removed_features = []
    rmse_history = []
    
    # Get baseline performance
    # Get baseline predictions
    baseline_predictions = get_predictions(model, dataloader, device)
   
    baseline_results = evaluate_predictions(baseline_predictions[0], baseline_predictions[1])

    baseline_quality_corr = baseline_results['quality_corr']
    baseline_authenticity_corr = baseline_results['authenticity_corr']

    baseline_corr = (baseline_quality_corr + baseline_authenticity_corr) / 2
    
    print(f"Baseline correlation: {baseline_corr:.4f}")
    
    # Track the best RMSE  
    # Iterate over the sorted indices and if removing a feature map improves performance, keep it removed
    for idx, (channel_idx, importance_score) in enumerate(sorted_importance_scores):
        channel_idx = int(channel_idx)
        
        # Temporarily zero out this feature map
        layer.weight[channel_idx, ...] = 0
        if layer.bias is not None:
            layer.bias[channel_idx] = 0
        
        # Evaluate model with feature map removed
        predictions = get_predictions(model, dataloader, device)
        results = evaluate_predictions(predictions[0], predictions[1])
        quality_corr = results['quality_corr']
        authenticity_corr = results['authenticity_corr']
        average_new_corr = (quality_corr + authenticity_corr) / 2

        
        print(f"Iteration {idx+1}/{len(sorted_importance_scores)}: " +
              f"Testing removal of channel {channel_idx}, " +
              f"Importance: {importance_score:.4f}, " +
              f"Correlation: {average_new_corr:.4f}")
        
        # Decide whether to keep this feature map removed
        if average_new_corr > baseline_corr:
            baseline_corr = average_new_corr
            removed_features.append(channel_idx)
            print(f"  ✓ IMPROVING: Zeroing out feature map {channel_idx}")
        else:
            # Restore the feature map
            layer.weight[channel_idx, ...] = original_weights[channel_idx, ...]
            if layer.bias is not None:
                layer.bias[channel_idx] = original_bias[channel_idx]
            print(f"  ✗ NOT IMPROVING: Keeping feature map {channel_idx}")
        
    
    # Final statistics
    print("\n------------------")
    print(f"Final correlation: {baseline_corr:.4f}")
    print(f"Improvement over baseline: {baseline_corr - baseline_corr:.4f}")
    print(f"Improvement over baseline: {baseline_corr - baseline_corr:.4f}")
    print(f"Feature reduction: {(len(removed_features)/len(sorted_importance_scores))*100:.1f}%")
    
    # Save the pruned model
    torch.save(model.state_dict(), model_path)
    
    return {
        'removed_features': removed_features,
        'baseline_corr': baseline_corr,
        'final_corr': baseline_corr,
        'improvement': baseline_corr - baseline_corr,
        'reduction_percentage': (len(removed_features)/len(sorted_importance_scores))*100,
        'rmse_history': rmse_history
    }

def remove_negative_impact_corr_feature_maps(model, dataloader, device, layer_name, sorted_corr_importance_scores, model_path='Weights/negative_impact_pruned_model.pth'):
    """
    Remove feature maps that have a negative impact on model performance based on importance scores (impotance score < 0).
    
    Args:
        model: The neural network model
        dataloader: DataLoader for evaluation
        device: Device to run the model on (cuda/cpu)
        layer_name: Name of the layer to optimize
        sorted_importance_scores: List of tuples (channel_index, importance_score) sorted by importance
        
    Returns:
        Dictionary with pruning results and performance metrics
    """
    model.eval()
    model.to(device)
    
    # Get the target layer
    dict_modules = dict(model.named_modules())
    layer = dict_modules[layer_name]
    
    # Create a backup of the original weights and bias
    original_weights = layer.weight.clone()
    original_bias = layer.bias.clone() if layer.bias is not None else None
    
    # Get baseline predictions
    baseline_predictions = get_predictions(model, dataloader, device)
   
    baseline_results = evaluate_predictions(baseline_predictions[0], baseline_predictions[1])

    baseline_quality_corr = baseline_results['quality_corr']

    # Initialize tracking variables
    removed_features = []
    
    # Iterate over the sorted indices and zero out all the feature maps that have a negative impact (importance > 0)

    for idx, (channel_idx, importance_score) in enumerate(sorted_corr_importance_scores):
        print(f"Iteration {idx} - Channel {channel_idx}: Importance score: {importance_score:.4f}")
        if importance_score > 0:
            channel_idx = int(channel_idx)
            layer.weight[channel_idx, ...] = 0
            if layer.bias is not None:
                layer.bias[channel_idx] = 0
            removed_features.append(channel_idx)

    # Get pruned results
    new_predictions = get_predictions(model, dataloader, device)
   
    new_results = evaluate_predictions(new_predictions[0], new_predictions[1])

    new_quality_corr = new_results['quality_corr']

    # Save the pruned model
    torch.save(model.state_dict(), model_path)

    # Restore original weights for future use
    layer.weight.data.copy_(original_weights)
    if layer.bias is not None:
        layer.bias.data.copy_(original_bias)

    
    return {
        'removed_features': removed_features,
        'baseline_corr': baseline_quality_corr,
        'final_corr': new_quality_corr,
        'improvement': baseline_quality_corr - new_quality_corr,
        'reduction_percentage': (len(removed_features)/len(sorted_corr_importance_scores))*100
    }

# %%
# layer to prune
layer = 'features.28'
# Prune the model

model = QualityPredictor()
model.load_state_dict(torch.load('Weights/VGG-16_finetuned_regression.pth'))
model.eval()
model.to(device)

delta_corr_importance_scores = compute_feature_map_importance(model, val_dataloader, device, layer)

del model

model_2 = QualityPredictor()
model_2.load_state_dict(torch.load('Weights/VGG-16_finetuned_regression.pth'))

remove_negative_impact_corr_pruning_results = remove_negative_impact_corr_feature_maps(model_2, val_dataloader, device, layer, delta_corr_importance_scores,  model_path='Weights/negative_impact_corr_pruned_model.pth')

del model_2

model_3 = QualityPredictor()
model_3.load_state_dict(torch.load('Weights/VGG-16_finetuned_regression.pth'))

remove_noisy_feature_maps = remove_noisy_feature_maps(model_3, val_dataloader, device, layer, delta_corr_importance_scores, model_path='Weights/noise_out_corr_pruned_model.pth')

del model_3
# Out:
# /tmp/ipykernel_226553/3114487485.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('Weights/VGG-16_finetuned_regression.pth'))
# /tmp/ipykernel_226553/3114487485.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_2.load_state_dict(torch.load('Weights/VGG-16_finetuned_regression.pth'))
# Iteration 0 - Channel 497.0: Importance score: 0.0082
# Iteration 1 - Channel 206.0: Importance score: 0.0073
# Iteration 2 - Channel 291.0: Importance score: 0.0068
# Iteration 3 - Channel 119.0: Importance score: 0.0055
# Iteration 4 - Channel 325.0: Importance score: 0.0045
# Iteration 5 - Channel 121.0: Importance score: 0.0043
# Iteration 6 - Channel 22.0: Importance score: 0.0040
# Iteration 7 - Channel 3.0: Importance score: 0.0036
# Iteration 8 - Channel 210.0: Importance score: 0.0036
# Iteration 9 - Channel 334.0: Importance score: 0.0035
# Iteration 10 - Channel 183.0: Importance score: 0.0033
# Iteration 11 - Channel 103.0: Importance score: 0.0032
# Iteration 12 - Channel 98.0: Importance score: 0.0031
# Iteration 13 - Channel 375.0: Importance score: 0.0031
# Iteration 14 - Channel 67.0: Importance score: 0.0030
# Iteration 15 - Channel 137.0: Importance score: 0.0029
# Iteration 16 - Channel 56.0: Importance score: 0.0029
# Iteration 17 - Channel 432.0: Importance score: 0.0029
# Iteration 18 - Channel 236.0: Importance score: 0.0027
# Iteration 19 - Channel 59.0: Importance score: 0.0027
# Iteration 20 - Channel 193.0: Importance score: 0.0026
# Iteration 21 - Channel 245.0: Importance score: 0.0026
# Iteration 22 - Channel 450.0: Importance score: 0.0026
# Iteration 23 - Channel 129.0: Importance score: 0.0026
# Iteration 24 - Channel 423.0: Importance score: 0.0026
# Iteration 25 - Channel 55.0: Importance score: 0.0026
# Iteration 26 - Channel 352.0: Importance score: 0.0025
# Iteration 27 - Channel 176.0: Importance score: 0.0024
# Iteration 28 - Channel 451.0: Importance score: 0.0023
# Iteration 29 - Channel 97.0: Importance score: 0.0023
# Iteration 30 - Channel 267.0: Importance score: 0.0023
# Iteration 31 - Channel 125.0: Importance score: 0.0022
# Iteration 32 - Channel 177.0: Importance score: 0.0022
# Iteration 33 - Channel 476.0: Importance score: 0.0022
# Iteration 34 - Channel 425.0: Importance score: 0.0022
# Iteration 4/512: Testing removal of channel 119, Importance: 0.0055, Correlation: 0.6399
#   ✓ IMPROVING: Zeroing out feature map 119
# Iteration 5/512: Testing removal of channel 325, Importance: 0.0045, Correlation: 0.6435
#   ✓ IMPROVING: Zeroing out feature map 325
# Iteration 6/512: Testing removal of channel 121, Importance: 0.0043, Correlation: 0.6446
#   ✓ IMPROVING: Zeroing out feature map 121
# Iteration 7/512: Testing removal of channel 22, Importance: 0.0040, Correlation: 0.6471
#   ✓ IMPROVING: Zeroing out feature map 22
# Iteration 8/512: Testing removal of channel 3, Importance: 0.0036, Correlation: 0.6504
#   ✓ IMPROVING: Zeroing out feature map 3
# Iteration 9/512: Testing removal of channel 210, Importance: 0.0036, Correlation: 0.6537
#   ✓ IMPROVING: Zeroing out feature map 210
# Iteration 10/512: Testing removal of channel 334, Importance: 0.0035, Correlation: 0.6554
#   ✓ IMPROVING: Zeroing out feature map 334
# Iteration 11/512: Testing removal of channel 183, Importance: 0.0033, Correlation: 0.6555
#   ✓ IMPROVING: Zeroing out feature map 183
# Iteration 12/512: Testing removal of channel 103, Importance: 0.0032, Correlation: 0.6545
#   ✗ NOT IMPROVING: Keeping feature map 103
# Iteration 13/512: Testing removal of channel 98, Importance: 0.0031, Correlation: 0.6559
#   ✓ IMPROVING: Zeroing out feature map 98
# Iteration 14/512: Testing removal of channel 375, Importance: 0.0031, Correlation: 0.6552
#   ✗ NOT IMPROVING: Keeping feature map 375
# Iteration 15/512: Testing removal of channel 67, Importance: 0.0030, Correlation: 0.6567
#   ✓ IMPROVING: Zeroing out feature map 67
# Iteration 16/512: Testing removal of channel 137, Importance: 0.0029, Correlation: 0.6589
#   ✓ IMPROVING: Zeroing out feature map 137
# Iteration 17/512: Testing removal of channel 56, Importance: 0.0029, Correlation: 0.6585
#   ✗ NOT IMPROVING: Keeping feature map 56
# Iteration 18/512: Testing removal of channel 432, Importance: 0.0029, Correlation: 0.6593
#   ✓ IMPROVING: Zeroing out feature map 432
# Iteration 19/512: Testing removal of channel 236, Importance: 0.0027, Correlation: 0.6619
#   ✓ IMPROVING: Zeroing out feature map 236
# Iteration 20/512: Testing removal of channel 59, Importance: 0.0027, Correlation: 0.6609
#   ✗ NOT IMPROVING: Keeping feature map 59
# Iteration 21/512: Testing removal of channel 193, Importance: 0.0026, Correlation: 0.6631
#   ✓ IMPROVING: Zeroing out feature map 193
# Iteration 22/512: Testing removal of channel 245, Importance: 0.0026, Correlation: 0.6631
#   ✓ IMPROVING: Zeroing out feature map 245
# Iteration 23/512: Testing removal of channel 450, Importance: 0.0026, Correlation: 0.6699
#   ✓ IMPROVING: Zeroing out feature map 450
# Iteration 24/512: Testing removal of channel 129, Importance: 0.0026, Correlation: 0.6706
#   ✓ IMPROVING: Zeroing out feature map 129
# Iteration 25/512: Testing removal of channel 423, Importance: 0.0026, Correlation: 0.6713
#   ✓ IMPROVING: Zeroing out feature map 423
# Iteration 26/512: Testing removal of channel 55, Importance: 0.0026, Correlation: 0.6741
#   ✓ IMPROVING: Zeroing out feature map 55
# Iteration 27/512: Testing removal of channel 352, Importance: 0.0025, Correlation: 0.6752
#   ✓ IMPROVING: Zeroing out feature map 352
# Iteration 28/512: Testing removal of channel 176, Importance: 0.0024, Correlation: 0.6748
#   ✗ NOT IMPROVING: Keeping feature map 176
# Iteration 29/512: Testing removal of channel 451, Importance: 0.0023, Correlation: 0.6744
#   ✗ NOT IMPROVING: Keeping feature map 451
# Iteration 30/512: Testing removal of channel 97, Importance: 0.0023, Correlation: 0.6725
#   ✗ NOT IMPROVING: Keeping feature map 97
# Iteration 31/512: Testing removal of channel 267, Importance: 0.0023, Correlation: 0.6761
#   ✓ IMPROVING: Zeroing out feature map 267
# Iteration 32/512: Testing removal of channel 125, Importance: 0.0022, Correlation: 0.6791
#   ✓ IMPROVING: Zeroing out feature map 125
# Iteration 33/512: Testing removal of channel 177, Importance: 0.0022, Correlation: 0.6795
#   ✓ IMPROVING: Zeroing out feature map 177
# Iteration 34/512: Testing removal of channel 476, Importance: 0.0022, Correlation: 0.6801
#   ✓ IMPROVING: Zeroing out feature map 476
# Iteration 35/512: Testing removal of channel 425, Importance: 0.0022, Correlation: 0.6790
#   ✗ NOT IMPROVING: Keeping feature map 425
# Iteration 36/512: Testing removal of channel 214, Importance: 0.0021, Correlation: 0.6797
#   ✗ NOT IMPROVING: Keeping feature map 214
# Iteration 37/512: Testing removal of channel 344, Importance: 0.0021, Correlation: 0.6810
#   ✓ IMPROVING: Zeroing out feature map 344
# Iteration 38/512: Testing removal of channel 141, Importance: 0.0021, Correlation: 0.6797
#   ✗ NOT IMPROVING: Keeping feature map 141
# Iteration 39/512: Testing removal of channel 168, Importance: 0.0020, Correlation: 0.6832
#   ✓ IMPROVING: Zeroing out feature map 168
# Iteration 40/512: Testing removal of channel 222, Importance: 0.0020, Correlation: 0.6833
#   ✓ IMPROVING: Zeroing out feature map 222
# Iteration 41/512: Testing removal of channel 21, Importance: 0.0020, Correlation: 0.6839
#   ✓ IMPROVING: Zeroing out feature map 21
# Iteration 42/512: Testing removal of channel 182, Importance: 0.0019, Correlation: 0.6845
#   ✓ IMPROVING: Zeroing out feature map 182
# Iteration 43/512: Testing removal of channel 107, Importance: 0.0019, Correlation: 0.6849
#   ✓ IMPROVING: Zeroing out feature map 107
# Iteration 44/512: Testing removal of channel 66, Importance: 0.0019, Correlation: 0.6869
#   ✓ IMPROVING: Zeroing out feature map 66
# Iteration 45/512: Testing removal of channel 226, Importance: 0.0019, Correlation: 0.6876
#   ✓ IMPROVING: Zeroing out feature map 226
# Iteration 46/512: Testing removal of channel 478, Importance: 0.0018, Correlation: 0.6861
#   ✗ NOT IMPROVING: Keeping feature map 478
# Iteration 47/512: Testing removal of channel 241, Importance: 0.0018, Correlation: 0.6853
#   ✗ NOT IMPROVING: Keeping feature map 241
# Iteration 48/512: Testing removal of channel 300, Importance: 0.0018, Correlation: 0.6894
#   ✓ IMPROVING: Zeroing out feature map 300
# Iteration 49/512: Testing removal of channel 131, Importance: 0.0018, Correlation: 0.6881
#   ✗ NOT IMPROVING: Keeping feature map 131
# Iteration 50/512: Testing removal of channel 62, Importance: 0.0018, Correlation: 0.6886
#   ✗ NOT IMPROVING: Keeping feature map 62
# Iteration 51/512: Testing removal of channel 149, Importance: 0.0018, Correlation: 0.6887
#   ✗ NOT IMPROVING: Keeping feature map 149
# Iteration 52/512: Testing removal of channel 184, Importance: 0.0017, Correlation: 0.6891
#   ✗ NOT IMPROVING: Keeping feature map 184
# Iteration 53/512: Testing removal of channel 147, Importance: 0.0017, Correlation: 0.6890
#   ✗ NOT IMPROVING: Keeping feature map 147
# Iteration 54/512: Testing removal of channel 353, Importance: 0.0017, Correlation: 0.6897
#   ✓ IMPROVING: Zeroing out feature map 353
# Iteration 55/512: Testing removal of channel 483, Importance: 0.0017, Correlation: 0.6874
#   ✗ NOT IMPROVING: Keeping feature map 483
# Iteration 56/512: Testing removal of channel 13, Importance: 0.0017, Correlation: 0.6899
#   ✓ IMPROVING: Zeroing out feature map 13
# Iteration 57/512: Testing removal of channel 441, Importance: 0.0017, Correlation: 0.6896
#   ✗ NOT IMPROVING: Keeping feature map 441
# Iteration 58/512: Testing removal of channel 501, Importance: 0.0016, Correlation: 0.6900
#   ✓ IMPROVING: Zeroing out feature map 501
# Iteration 59/512: Testing removal of channel 282, Importance: 0.0016, Correlation: 0.6896
#   ✗ NOT IMPROVING: Keeping feature map 282
# Iteration 60/512: Testing removal of channel 261, Importance: 0.0016, Correlation: 0.6915
#   ✓ IMPROVING: Zeroing out feature map 261
# Iteration 61/512: Testing removal of channel 123, Importance: 0.0016, Correlation: 0.6939
#   ✓ IMPROVING: Zeroing out feature map 123
# Iteration 62/512: Testing removal of channel 305, Importance: 0.0016, Correlation: 0.6936
#   ✗ NOT IMPROVING: Keeping feature map 305
# Iteration 63/512: Testing removal of channel 263, Importance: 0.0015, Correlation: 0.6960
#   ✓ IMPROVING: Zeroing out feature map 263
# Iteration 64/512: Testing removal of channel 199, Importance: 0.0015, Correlation: 0.6960
#   ✓ IMPROVING: Zeroing out feature map 199
# Iteration 65/512: Testing removal of channel 215, Importance: 0.0015, Correlation: 0.6983
#   ✓ IMPROVING: Zeroing out feature map 215
# Iteration 66/512: Testing removal of channel 195, Importance: 0.0015, Correlation: 0.6984
#   ✓ IMPROVING: Zeroing out feature map 195
# Iteration 67/512: Testing removal of channel 482, Importance: 0.0014, Correlation: 0.6978
#   ✗ NOT IMPROVING: Keeping feature map 482
# Iteration 68/512: Testing removal of channel 105, Importance: 0.0014, Correlation: 0.6988
#   ✓ IMPROVING: Zeroing out feature map 105
# Iteration 69/512: Testing removal of channel 302, Importance: 0.0014, Correlation: 0.6981
#   ✗ NOT IMPROVING: Keeping feature map 302
# Iteration 70/512: Testing removal of channel 91, Importance: 0.0014, Correlation: 0.6985
#   ✗ NOT IMPROVING: Keeping feature map 91
# Iteration 71/512: Testing removal of channel 419, Importance: 0.0014, Correlation: 0.7001
#   ✓ IMPROVING: Zeroing out feature map 419
# Iteration 72/512: Testing removal of channel 415, Importance: 0.0013, Correlation: 0.6972
#   ✗ NOT IMPROVING: Keeping feature map 415
# Iteration 73/512: Testing removal of channel 235, Importance: 0.0013, Correlation: 0.6998
#   ✗ NOT IMPROVING: Keeping feature map 235
# Iteration 74/512: Testing removal of channel 330, Importance: 0.0013, Correlation: 0.6980
#   ✗ NOT IMPROVING: Keeping feature map 330
# Iteration 75/512: Testing removal of channel 213, Importance: 0.0013, Correlation: 0.6999
#   ✗ NOT IMPROVING: Keeping feature map 213
# Iteration 76/512: Testing removal of channel 57, Importance: 0.0013, Correlation: 0.6978
#   ✗ NOT IMPROVING: Keeping feature map 57
# Iteration 77/512: Testing removal of channel 335, Importance: 0.0013, Correlation: 0.6998
#   ✗ NOT IMPROVING: Keeping feature map 335
# Iteration 78/512: Testing removal of channel 45, Importance: 0.0012, Correlation: 0.7004
#   ✓ IMPROVING: Zeroing out feature map 45
# Iteration 79/512: Testing removal of channel 487, Importance: 0.0012, Correlation: 0.7011
#   ✓ IMPROVING: Zeroing out feature map 487
# Iteration 80/512: Testing removal of channel 414, Importance: 0.0012, Correlation: 0.7001
#   ✗ NOT IMPROVING: Keeping feature map 414
# Iteration 81/512: Testing removal of channel 163, Importance: 0.0012, Correlation: 0.7002
#   ✗ NOT IMPROVING: Keeping feature map 163
# Iteration 82/512: Testing removal of channel 189, Importance: 0.0011, Correlation: 0.7010
#   ✗ NOT IMPROVING: Keeping feature map 189
# Iteration 83/512: Testing removal of channel 73, Importance: 0.0011, Correlation: 0.6997
#   ✗ NOT IMPROVING: Keeping feature map 73
# Iteration 84/512: Testing removal of channel 343, Importance: 0.0011, Correlation: 0.7001
#   ✗ NOT IMPROVING: Keeping feature map 343
# Iteration 85/512: Testing removal of channel 448, Importance: 0.0011, Correlation: 0.7008
#   ✗ NOT IMPROVING: Keeping feature map 448
# Iteration 86/512: Testing removal of channel 321, Importance: 0.0011, Correlation: 0.7016
#   ✓ IMPROVING: Zeroing out feature map 321
# Iteration 87/512: Testing removal of channel 25, Importance: 0.0011, Correlation: 0.7014
#   ✗ NOT IMPROVING: Keeping feature map 25
# Iteration 88/512: Testing removal of channel 95, Importance: 0.0011, Correlation: 0.7001
#   ✗ NOT IMPROVING: Keeping feature map 95
# Iteration 89/512: Testing removal of channel 113, Importance: 0.0011, Correlation: 0.6982
#   ✗ NOT IMPROVING: Keeping feature map 113
# Iteration 90/512: Testing removal of channel 83, Importance: 0.0011, Correlation: 0.7014
#   ✗ NOT IMPROVING: Keeping feature map 83
# Iteration 91/512: Testing removal of channel 134, Importance: 0.0010, Correlation: 0.6998
#   ✗ NOT IMPROVING: Keeping feature map 134
# Iteration 92/512: Testing removal of channel 301, Importance: 0.0010, Correlation: 0.7007
#   ✗ NOT IMPROVING: Keeping feature map 301
# Iteration 93/512: Testing removal of channel 490, Importance: 0.0010, Correlation: 0.7020
#   ✓ IMPROVING: Zeroing out feature map 490
# Iteration 94/512: Testing removal of channel 192, Importance: 0.0010, Correlation: 0.7016
#   ✗ NOT IMPROVING: Keeping feature map 192
# Iteration 95/512: Testing removal of channel 287, Importance: 0.0010, Correlation: 0.7018
#   ✗ NOT IMPROVING: Keeping feature map 287
# Iteration 96/512: Testing removal of channel 86, Importance: 0.0009, Correlation: 0.7022
#   ✓ IMPROVING: Zeroing out feature map 86
# Iteration 97/512: Testing removal of channel 0, Importance: 0.0009, Correlation: 0.7009
#   ✗ NOT IMPROVING: Keeping feature map 0
# Iteration 98/512: Testing removal of channel 453, Importance: 0.0009, Correlation: 0.7024
#   ✓ IMPROVING: Zeroing out feature map 453
# Iteration 99/512: Testing removal of channel 251, Importance: 0.0009, Correlation: 0.7021
#   ✗ NOT IMPROVING: Keeping feature map 251
# Iteration 100/512: Testing removal of channel 467, Importance: 0.0009, Correlation: 0.7033
#   ✓ IMPROVING: Zeroing out feature map 467
# Iteration 101/512: Testing removal of channel 477, Importance: 0.0009, Correlation: 0.7043
#   ✓ IMPROVING: Zeroing out feature map 477
# Iteration 102/512: Testing removal of channel 458, Importance: 0.0009, Correlation: 0.7042
#   ✗ NOT IMPROVING: Keeping feature map 458
# Iteration 103/512: Testing removal of channel 127, Importance: 0.0009, Correlation: 0.7047
#   ✓ IMPROVING: Zeroing out feature map 127
# Iteration 104/512: Testing removal of channel 292, Importance: 0.0008, Correlation: 0.7044
#   ✗ NOT IMPROVING: Keeping feature map 292
# Iteration 105/512: Testing removal of channel 289, Importance: 0.0008, Correlation: 0.7071
#   ✓ IMPROVING: Zeroing out feature map 289
# Iteration 106/512: Testing removal of channel 318, Importance: 0.0008, Correlation: 0.7058
#   ✗ NOT IMPROVING: Keeping feature map 318
# Iteration 107/512: Testing removal of channel 429, Importance: 0.0008, Correlation: 0.7065
#   ✗ NOT IMPROVING: Keeping feature map 429
# Iteration 108/512: Testing removal of channel 345, Importance: 0.0008, Correlation: 0.7068
#   ✗ NOT IMPROVING: Keeping feature map 345
# Iteration 109/512: Testing removal of channel 475, Importance: 0.0008, Correlation: 0.7076
#   ✓ IMPROVING: Zeroing out feature map 475
# Iteration 110/512: Testing removal of channel 70, Importance: 0.0008, Correlation: 0.7077
#   ✓ IMPROVING: Zeroing out feature map 70
# Iteration 111/512: Testing removal of channel 371, Importance: 0.0008, Correlation: 0.7073
#   ✗ NOT IMPROVING: Keeping feature map 371
# Iteration 112/512: Testing removal of channel 447, Importance: 0.0008, Correlation: 0.7074
#   ✗ NOT IMPROVING: Keeping feature map 447
# Iteration 113/512: Testing removal of channel 186, Importance: 0.0008, Correlation: 0.7069
#   ✗ NOT IMPROVING: Keeping feature map 186
# Iteration 114/512: Testing removal of channel 187, Importance: 0.0008, Correlation: 0.7063
#   ✗ NOT IMPROVING: Keeping feature map 187
# Iteration 115/512: Testing removal of channel 484, Importance: 0.0008, Correlation: 0.7077
#   ✓ IMPROVING: Zeroing out feature map 484
# Iteration 116/512: Testing removal of channel 455, Importance: 0.0007, Correlation: 0.7079
#   ✓ IMPROVING: Zeroing out feature map 455
# Iteration 117/512: Testing removal of channel 40, Importance: 0.0007, Correlation: 0.7076
#   ✗ NOT IMPROVING: Keeping feature map 40
# Iteration 118/512: Testing removal of channel 18, Importance: 0.0007, Correlation: 0.7077
#   ✗ NOT IMPROVING: Keeping feature map 18
# Iteration 119/512: Testing removal of channel 348, Importance: 0.0007, Correlation: 0.7071
#   ✗ NOT IMPROVING: Keeping feature map 348
# Iteration 120/512: Testing removal of channel 364, Importance: 0.0007, Correlation: 0.7094
#   ✓ IMPROVING: Zeroing out feature map 364
# Iteration 121/512: Testing removal of channel 404, Importance: 0.0007, Correlation: 0.7086
#   ✗ NOT IMPROVING: Keeping feature map 404
# Iteration 122/512: Testing removal of channel 369, Importance: 0.0007, Correlation: 0.7110
#   ✓ IMPROVING: Zeroing out feature map 369
# ...
#   ✗ NOT IMPROVING: Keeping feature map 219
# Iteration 396/512: Testing removal of channel 402, Importance: -0.0021, Correlation: 0.7615
#   ✗ NOT IMPROVING: Keeping feature map 402
# Iteration 397/512: Testing removal of channel 306, Importance: -0.0021, Correlation: 0.7601
#   ✗ NOT IMPROVING: Keeping feature map 306
# Iteration 398/512: Testing removal of channel 430, Importance: -0.0021, Correlation: 0.7592
#   ✗ NOT IMPROVING: Keeping feature map 430
# Iteration 399/512: Testing removal of channel 392, Importance: -0.0021, Correlation: 0.7610
#   ✗ NOT IMPROVING: Keeping feature map 392
# Iteration 400/512: Testing removal of channel 9, Importance: -0.0021, Correlation: 0.7607
#   ✗ NOT IMPROVING: Keeping feature map 9
# Iteration 401/512: Testing removal of channel 382, Importance: -0.0021, Correlation: 0.7624
#   ✓ IMPROVING: Zeroing out feature map 382
# Iteration 402/512: Testing removal of channel 406, Importance: -0.0022, Correlation: 0.7635
#   ✓ IMPROVING: Zeroing out feature map 406
# Iteration 403/512: Testing removal of channel 358, Importance: -0.0022, Correlation: 0.7623
#   ✗ NOT IMPROVING: Keeping feature map 358
# Iteration 404/512: Testing removal of channel 111, Importance: -0.0022, Correlation: 0.7626
#   ✗ NOT IMPROVING: Keeping feature map 111
# Iteration 405/512: Testing removal of channel 188, Importance: -0.0022, Correlation: 0.7624
#   ✗ NOT IMPROVING: Keeping feature map 188
# Iteration 406/512: Testing removal of channel 173, Importance: -0.0022, Correlation: 0.7610
#   ✗ NOT IMPROVING: Keeping feature map 173
# Iteration 407/512: Testing removal of channel 230, Importance: -0.0022, Correlation: 0.7632
#   ✗ NOT IMPROVING: Keeping feature map 230
# Iteration 408/512: Testing removal of channel 337, Importance: -0.0022, Correlation: 0.7628
#   ✗ NOT IMPROVING: Keeping feature map 337
# Iteration 409/512: Testing removal of channel 424, Importance: -0.0023, Correlation: 0.7623
#   ✗ NOT IMPROVING: Keeping feature map 424
# Iteration 410/512: Testing removal of channel 346, Importance: -0.0024, Correlation: 0.7580
#   ✗ NOT IMPROVING: Keeping feature map 346
# Iteration 411/512: Testing removal of channel 393, Importance: -0.0024, Correlation: 0.7624
#   ✗ NOT IMPROVING: Keeping feature map 393
# Iteration 412/512: Testing removal of channel 15, Importance: -0.0024, Correlation: 0.7632
#   ✗ NOT IMPROVING: Keeping feature map 15
# Iteration 413/512: Testing removal of channel 82, Importance: -0.0024, Correlation: 0.7642
#   ✓ IMPROVING: Zeroing out feature map 82
# Iteration 414/512: Testing removal of channel 35, Importance: -0.0024, Correlation: 0.7623
#   ✗ NOT IMPROVING: Keeping feature map 35
# Iteration 415/512: Testing removal of channel 508, Importance: -0.0025, Correlation: 0.7594
#   ✗ NOT IMPROVING: Keeping feature map 508
# Iteration 416/512: Testing removal of channel 459, Importance: -0.0026, Correlation: 0.7638
#   ✗ NOT IMPROVING: Keeping feature map 459
# Iteration 417/512: Testing removal of channel 171, Importance: -0.0026, Correlation: 0.7615
#   ✗ NOT IMPROVING: Keeping feature map 171
# Iteration 418/512: Testing removal of channel 160, Importance: -0.0027, Correlation: 0.7617
#   ✗ NOT IMPROVING: Keeping feature map 160
# Iteration 419/512: Testing removal of channel 298, Importance: -0.0027, Correlation: 0.7606
#   ✗ NOT IMPROVING: Keeping feature map 298
# Iteration 420/512: Testing removal of channel 426, Importance: -0.0027, Correlation: 0.7654
#   ✓ IMPROVING: Zeroing out feature map 426
# Iteration 421/512: Testing removal of channel 253, Importance: -0.0027, Correlation: 0.7639
#   ✗ NOT IMPROVING: Keeping feature map 253
# Iteration 422/512: Testing removal of channel 317, Importance: -0.0028, Correlation: 0.7648
#   ✗ NOT IMPROVING: Keeping feature map 317
# Iteration 423/512: Testing removal of channel 399, Importance: -0.0028, Correlation: 0.7642
#   ✗ NOT IMPROVING: Keeping feature map 399
# Iteration 424/512: Testing removal of channel 314, Importance: -0.0028, Correlation: 0.7643
#   ✗ NOT IMPROVING: Keeping feature map 314
# Iteration 425/512: Testing removal of channel 370, Importance: -0.0028, Correlation: 0.7658
#   ✓ IMPROVING: Zeroing out feature map 370
# Iteration 426/512: Testing removal of channel 150, Importance: -0.0028, Correlation: 0.7671
#   ✓ IMPROVING: Zeroing out feature map 150
# Iteration 427/512: Testing removal of channel 1, Importance: -0.0028, Correlation: 0.7673
#   ✓ IMPROVING: Zeroing out feature map 1
# Iteration 428/512: Testing removal of channel 359, Importance: -0.0028, Correlation: 0.7669
#   ✗ NOT IMPROVING: Keeping feature map 359
# Iteration 429/512: Testing removal of channel 286, Importance: -0.0028, Correlation: 0.7686
#   ✓ IMPROVING: Zeroing out feature map 286
# Iteration 430/512: Testing removal of channel 170, Importance: -0.0029, Correlation: 0.7688
#   ✓ IMPROVING: Zeroing out feature map 170
# Iteration 431/512: Testing removal of channel 350, Importance: -0.0029, Correlation: 0.7686
#   ✗ NOT IMPROVING: Keeping feature map 350
# Iteration 432/512: Testing removal of channel 456, Importance: -0.0029, Correlation: 0.7673
#   ✗ NOT IMPROVING: Keeping feature map 456
# Iteration 433/512: Testing removal of channel 309, Importance: -0.0030, Correlation: 0.7673
#   ✗ NOT IMPROVING: Keeping feature map 309
# Iteration 434/512: Testing removal of channel 495, Importance: -0.0030, Correlation: 0.7677
#   ✗ NOT IMPROVING: Keeping feature map 495
# Iteration 435/512: Testing removal of channel 254, Importance: -0.0030, Correlation: 0.7676
#   ✗ NOT IMPROVING: Keeping feature map 254
# Iteration 436/512: Testing removal of channel 17, Importance: -0.0031, Correlation: 0.7676
#   ✗ NOT IMPROVING: Keeping feature map 17
# Iteration 437/512: Testing removal of channel 366, Importance: -0.0031, Correlation: 0.7688
#   ✓ IMPROVING: Zeroing out feature map 366
# Iteration 438/512: Testing removal of channel 158, Importance: -0.0031, Correlation: 0.7665
#   ✗ NOT IMPROVING: Keeping feature map 158
# Iteration 439/512: Testing removal of channel 297, Importance: -0.0032, Correlation: 0.7683
#   ✗ NOT IMPROVING: Keeping feature map 297
# Iteration 440/512: Testing removal of channel 397, Importance: -0.0032, Correlation: 0.7677
#   ✗ NOT IMPROVING: Keeping feature map 397
# Iteration 441/512: Testing removal of channel 492, Importance: -0.0032, Correlation: 0.7695
#   ✓ IMPROVING: Zeroing out feature map 492
# Iteration 442/512: Testing removal of channel 68, Importance: -0.0033, Correlation: 0.7679
#   ✗ NOT IMPROVING: Keeping feature map 68
# Iteration 443/512: Testing removal of channel 100, Importance: -0.0033, Correlation: 0.7699
#   ✓ IMPROVING: Zeroing out feature map 100
# Iteration 444/512: Testing removal of channel 374, Importance: -0.0033, Correlation: 0.7693
#   ✗ NOT IMPROVING: Keeping feature map 374
# Iteration 445/512: Testing removal of channel 276, Importance: -0.0033, Correlation: 0.7697
#   ✗ NOT IMPROVING: Keeping feature map 276
# Iteration 446/512: Testing removal of channel 269, Importance: -0.0033, Correlation: 0.7674
#   ✗ NOT IMPROVING: Keeping feature map 269
# Iteration 447/512: Testing removal of channel 81, Importance: -0.0034, Correlation: 0.7674
#   ✗ NOT IMPROVING: Keeping feature map 81
# Iteration 448/512: Testing removal of channel 507, Importance: -0.0034, Correlation: 0.7684
#   ✗ NOT IMPROVING: Keeping feature map 507
# Iteration 449/512: Testing removal of channel 293, Importance: -0.0034, Correlation: 0.7692
#   ✗ NOT IMPROVING: Keeping feature map 293
# Iteration 450/512: Testing removal of channel 243, Importance: -0.0035, Correlation: 0.7684
#   ✗ NOT IMPROVING: Keeping feature map 243
# Iteration 451/512: Testing removal of channel 418, Importance: -0.0035, Correlation: 0.7695
#   ✗ NOT IMPROVING: Keeping feature map 418
# Iteration 452/512: Testing removal of channel 431, Importance: -0.0035, Correlation: 0.7691
#   ✗ NOT IMPROVING: Keeping feature map 431
# Iteration 453/512: Testing removal of channel 433, Importance: -0.0036, Correlation: 0.7704
#   ✓ IMPROVING: Zeroing out feature map 433
# Iteration 454/512: Testing removal of channel 400, Importance: -0.0036, Correlation: 0.7684
#   ✗ NOT IMPROVING: Keeping feature map 400
# Iteration 455/512: Testing removal of channel 323, Importance: -0.0036, Correlation: 0.7701
#   ✗ NOT IMPROVING: Keeping feature map 323
# Iteration 456/512: Testing removal of channel 363, Importance: -0.0036, Correlation: 0.7704
#   ✗ NOT IMPROVING: Keeping feature map 363
# Iteration 457/512: Testing removal of channel 313, Importance: -0.0036, Correlation: 0.7702
#   ✗ NOT IMPROVING: Keeping feature map 313
# Iteration 458/512: Testing removal of channel 94, Importance: -0.0036, Correlation: 0.7683
#   ✗ NOT IMPROVING: Keeping feature map 94
# Iteration 459/512: Testing removal of channel 444, Importance: -0.0036, Correlation: 0.7620
#   ✗ NOT IMPROVING: Keeping feature map 444
# Iteration 460/512: Testing removal of channel 504, Importance: -0.0037, Correlation: 0.7702
#   ✗ NOT IMPROVING: Keeping feature map 504
# Iteration 461/512: Testing removal of channel 394, Importance: -0.0037, Correlation: 0.7702
#   ✗ NOT IMPROVING: Keeping feature map 394
# Iteration 462/512: Testing removal of channel 108, Importance: -0.0037, Correlation: 0.7671
#   ✗ NOT IMPROVING: Keeping feature map 108
# Iteration 463/512: Testing removal of channel 240, Importance: -0.0037, Correlation: 0.7700
#   ✗ NOT IMPROVING: Keeping feature map 240
# Iteration 464/512: Testing removal of channel 262, Importance: -0.0038, Correlation: 0.7690
#   ✗ NOT IMPROVING: Keeping feature map 262
# Iteration 465/512: Testing removal of channel 225, Importance: -0.0038, Correlation: 0.7692
#   ✗ NOT IMPROVING: Keeping feature map 225
# Iteration 466/512: Testing removal of channel 272, Importance: -0.0038, Correlation: 0.7691
#   ✗ NOT IMPROVING: Keeping feature map 272
# Iteration 467/512: Testing removal of channel 88, Importance: -0.0038, Correlation: 0.7698
#   ✗ NOT IMPROVING: Keeping feature map 88
# Iteration 468/512: Testing removal of channel 503, Importance: -0.0039, Correlation: 0.7685
#   ✗ NOT IMPROVING: Keeping feature map 503
# Iteration 469/512: Testing removal of channel 202, Importance: -0.0040, Correlation: 0.7701
#   ✗ NOT IMPROVING: Keeping feature map 202
# Iteration 470/512: Testing removal of channel 30, Importance: -0.0041, Correlation: 0.7702
#   ✗ NOT IMPROVING: Keeping feature map 30
# Iteration 471/512: Testing removal of channel 342, Importance: -0.0041, Correlation: 0.7679
#   ✗ NOT IMPROVING: Keeping feature map 342
# Iteration 472/512: Testing removal of channel 124, Importance: -0.0042, Correlation: 0.7712
#   ✓ IMPROVING: Zeroing out feature map 124
# Iteration 473/512: Testing removal of channel 229, Importance: -0.0042, Correlation: 0.7719
#   ✓ IMPROVING: Zeroing out feature map 229
# Iteration 474/512: Testing removal of channel 76, Importance: -0.0042, Correlation: 0.7726
#   ✓ IMPROVING: Zeroing out feature map 76
# Iteration 475/512: Testing removal of channel 491, Importance: -0.0043, Correlation: 0.7721
#   ✗ NOT IMPROVING: Keeping feature map 491
# Iteration 476/512: Testing removal of channel 280, Importance: -0.0043, Correlation: 0.7726
#   ✓ IMPROVING: Zeroing out feature map 280
# Iteration 477/512: Testing removal of channel 145, Importance: -0.0043, Correlation: 0.7713
#   ✗ NOT IMPROVING: Keeping feature map 145
# Iteration 478/512: Testing removal of channel 268, Importance: -0.0044, Correlation: 0.7723
#   ✗ NOT IMPROVING: Keeping feature map 268
# Iteration 479/512: Testing removal of channel 288, Importance: -0.0044, Correlation: 0.7728
#   ✓ IMPROVING: Zeroing out feature map 288
# Iteration 480/512: Testing removal of channel 436, Importance: -0.0044, Correlation: 0.7712
#   ✗ NOT IMPROVING: Keeping feature map 436
# Iteration 481/512: Testing removal of channel 493, Importance: -0.0046, Correlation: 0.7715
#   ✗ NOT IMPROVING: Keeping feature map 493
# Iteration 482/512: Testing removal of channel 316, Importance: -0.0047, Correlation: 0.7704
#   ✗ NOT IMPROVING: Keeping feature map 316
# Iteration 483/512: Testing removal of channel 194, Importance: -0.0049, Correlation: 0.7704
#   ✗ NOT IMPROVING: Keeping feature map 194
# Iteration 484/512: Testing removal of channel 376, Importance: -0.0049, Correlation: 0.7693
#   ✗ NOT IMPROVING: Keeping feature map 376
# Iteration 485/512: Testing removal of channel 114, Importance: -0.0049, Correlation: 0.7713
#   ✗ NOT IMPROVING: Keeping feature map 114
# Iteration 486/512: Testing removal of channel 228, Importance: -0.0049, Correlation: 0.7707
#   ✗ NOT IMPROVING: Keeping feature map 228
# Iteration 487/512: Testing removal of channel 295, Importance: -0.0050, Correlation: 0.7709
#   ✗ NOT IMPROVING: Keeping feature map 295
# Iteration 488/512: Testing removal of channel 167, Importance: -0.0051, Correlation: 0.7718
#   ✗ NOT IMPROVING: Keeping feature map 167
# Iteration 489/512: Testing removal of channel 77, Importance: -0.0051, Correlation: 0.7707
#   ✗ NOT IMPROVING: Keeping feature map 77
# Iteration 490/512: Testing removal of channel 179, Importance: -0.0051, Correlation: 0.7730
#   ✓ IMPROVING: Zeroing out feature map 179
# Iteration 491/512: Testing removal of channel 312, Importance: -0.0053, Correlation: 0.7709
#   ✗ NOT IMPROVING: Keeping feature map 312
# Iteration 492/512: Testing removal of channel 118, Importance: -0.0054, Correlation: 0.7673
#   ✗ NOT IMPROVING: Keeping feature map 118
# Iteration 493/512: Testing removal of channel 37, Importance: -0.0055, Correlation: 0.7714
#   ✗ NOT IMPROVING: Keeping feature map 37
# Iteration 494/512: Testing removal of channel 379, Importance: -0.0055, Correlation: 0.7731
#   ✓ IMPROVING: Zeroing out feature map 379
# Iteration 495/512: Testing removal of channel 135, Importance: -0.0057, Correlation: 0.7703
#   ✗ NOT IMPROVING: Keeping feature map 135
# Iteration 496/512: Testing removal of channel 128, Importance: -0.0059, Correlation: 0.7731
#   ✗ NOT IMPROVING: Keeping feature map 128
# Iteration 497/512: Testing removal of channel 90, Importance: -0.0061, Correlation: 0.7723
#   ✗ NOT IMPROVING: Keeping feature map 90
# Iteration 498/512: Testing removal of channel 208, Importance: -0.0062, Correlation: 0.7696
#   ✗ NOT IMPROVING: Keeping feature map 208
# Iteration 499/512: Testing removal of channel 339, Importance: -0.0063, Correlation: 0.7714
#   ✗ NOT IMPROVING: Keeping feature map 339
# Iteration 500/512: Testing removal of channel 403, Importance: -0.0071, Correlation: 0.7738
#   ✓ IMPROVING: Zeroing out feature map 403
# Iteration 501/512: Testing removal of channel 259, Importance: -0.0074, Correlation: 0.7704
#   ✗ NOT IMPROVING: Keeping feature map 259
# Iteration 502/512: Testing removal of channel 33, Importance: -0.0075, Correlation: 0.7682
#   ✗ NOT IMPROVING: Keeping feature map 33
# Iteration 503/512: Testing removal of channel 72, Importance: -0.0076, Correlation: 0.7743
#   ✓ IMPROVING: Zeroing out feature map 72
# Iteration 504/512: Testing removal of channel 172, Importance: -0.0079, Correlation: 0.7739
#   ✗ NOT IMPROVING: Keeping feature map 172
# Iteration 505/512: Testing removal of channel 468, Importance: -0.0080, Correlation: 0.7674
#   ✗ NOT IMPROVING: Keeping feature map 468
# Iteration 506/512: Testing removal of channel 63, Importance: -0.0081, Correlation: 0.7727
#   ✗ NOT IMPROVING: Keeping feature map 63
# Iteration 507/512: Testing removal of channel 11, Importance: -0.0085, Correlation: 0.7711
#   ✗ NOT IMPROVING: Keeping feature map 11
# Iteration 508/512: Testing removal of channel 23, Importance: -0.0087, Correlation: 0.7715
#   ✗ NOT IMPROVING: Keeping feature map 23
# Iteration 509/512: Testing removal of channel 410, Importance: -0.0087, Correlation: 0.7715
#   ✗ NOT IMPROVING: Keeping feature map 410
# Iteration 510/512: Testing removal of channel 232, Importance: -0.0104, Correlation: 0.7719
#   ✗ NOT IMPROVING: Keeping feature map 232
# Iteration 511/512: Testing removal of channel 479, Importance: -0.0159, Correlation: 0.7676
#   ✗ NOT IMPROVING: Keeping feature map 479
# Iteration 512/512: Testing removal of channel 439, Importance: -0.0159, Correlation: 0.7638
#   ✗ NOT IMPROVING: Keeping feature map 439
#
# ------------------
# Final correlation: 0.7743
# Improvement over baseline: 0.0000
# Improvement over baseline: 0.0000
# Feature reduction: 34.4%

# %%
baseline_model = QualityPredictor()
baseline_model.load_state_dict(torch.load('Weights/VGG-16_finetuned_regression.pth'))

baseline_predictions = get_predictions(baseline_model, test_dataloader, device)
baseline_results = evaluate_predictions(baseline_predictions[0], baseline_predictions[1])


remove_negative_impact_corr_pruned_model = QualityPredictor()
remove_negative_impact_corr_pruned_model.load_state_dict(torch.load('Weights/negative_impact_corr_pruned_model.pth'))

remove_negative_impact_corr_predictions = get_predictions(remove_negative_impact_corr_pruned_model, test_dataloader, device)
remove_negative_impact_corr_results = evaluate_predictions(remove_negative_impact_corr_predictions[0], remove_negative_impact_corr_predictions[1])


noise_out_corr_pruned_model = QualityPredictor()
noise_out_corr_pruned_model.load_state_dict(torch.load('Weights/noise_out_corr_pruned_model.pth'))

noise_out_corr_predictions = get_predictions(noise_out_corr_pruned_model, test_dataloader, device)
noise_out_corr_results = evaluate_predictions(noise_out_corr_predictions[0], noise_out_corr_predictions[1])

print('Baseline Model Results:')
print(baseline_results)

print('Remove Negative Impact Correlation Pruned Model Results:')
print(remove_negative_impact_corr_results)

print('Noise Out Correlation Pruned Model Results:')
print(noise_out_corr_results)
# Out:
# /tmp/ipykernel_226553/2702022483.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   baseline_model.load_state_dict(torch.load('Weights/VGG-16_finetuned_regression.pth'))
# /tmp/ipykernel_226553/2702022483.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   remove_negative_impact_corr_pruned_model.load_state_dict(torch.load('Weights/negative_impact_corr_pruned_model.pth'))
# /tmp/ipykernel_226553/2702022483.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   noise_out_corr_pruned_model.load_state_dict(torch.load('Weights/noise_out_corr_pruned_model.pth'))
# Baseline Model Results:
# {'quality_corr': np.float64(0.6532543967777217), 'authenticity_corr': np.float64(0.6277643709092171), 'quality_rmse': np.float32(11.410385), 'authenticity_rmse': np.float32(10.7469015)}
# Remove Negative Impact Correlation Pruned Model Results:
# {'quality_corr': np.float64(0.6662902133717598), 'authenticity_corr': np.float64(0.5496953072101946), 'quality_rmse': np.float32(14.828631), 'authenticity_rmse': np.float32(15.409183)}
# Noise Out Correlation Pruned Model Results:
# {'quality_corr': np.float64(0.6543967777218354), 'authenticity_corr': np.float64(0.5937082241011127), 'quality_rmse': np.float32(18.474422), 'authenticity_rmse': np.float32(18.391764)}

# %%
# Create a function that extract the indices of the zeroed out feature maps in a convolutional layer

def get_zeroed_feature_maps(model, layer_name):
    """
    Get the indices of the zeroed out feature maps in a convolutional layer.

    Args:
        model (nn.Module): The neural network model.
        layer_name (str): The name of the convolutional layer.

    Returns:
        list: The indices of the zeroed out feature maps.
    """
    dict_modules = dict(model.named_modules())
    layer = dict_modules[layer_name]
    zeroed_feature_maps = []

    for i, weight in enumerate(layer.weight):
        if torch.all(weight == 0):
            zeroed_feature_maps.append(i)
    zeroed_feature_maps.sort()

    num_zeroed = len(zeroed_feature_maps)

    return zeroed_feature_maps, num_zeroed

# Get the zeroed out feature maps in the 'features.28' layer of the noisy pruned model
_, noisy_num_zeroed = get_zeroed_feature_maps(noise_out_corr_pruned_model, 'features.28')

# Get the zeroed out feature maps in the 'features.28' layer of the negative impact pruned model
_, negative_impact_num_zeroed = get_zeroed_feature_maps(remove_negative_impact_corr_pruned_model, 'features.28')

print(f"Noisy pruned model: {noisy_num_zeroed} zeroed out feature maps")

print(f"Negative impact pruned model: {negative_impact_num_zeroed} zeroed out feature maps")
# Out:
# Noisy pruned model: 176 zeroed out feature maps
# Negative impact pruned model: 178 zeroed out feature maps

# %% [markdown]
# # Model Evaluation Results
#
# ## Test Loss Comparison
#
# | Model | Test Loss | Variation from Baseline | Number of removed features |
# |-------|-----------|-------------------------| --------------------------|
# | RMSE Baseline | 112.4063 | - | - |
# | Best RMSE subset pruned (removed only the individual features with negative impact on RSME if zeroed) | 111.8710 | -0.48% | -185 |
# | Best RMSE subset Pruned (iterative zeroing) | 66.3359 | -40.99% | -133 |
#
# ## Correlation Results
# | Model | Quality Correlation | Variation from Baseline | Number of removed features |
# |-------|---------------------|-------------------------| --------------------------|
# | Corr Baseline | 0.6532543967777217 | - | - |
# | Remove Negative Impact Pruned (removed only the individual features with negative impact on corr if zeroed) | 0.6662902133717598 | +2.00% | -176 |
# | Noise Out Pruned (iterative zeroing) | 0.6543967777218354 | +0.17% | -178 |
